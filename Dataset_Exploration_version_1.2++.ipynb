# %% [markdown]
# # Data Exploration of Indicators Dataset

# %% [markdown]
# #### In this notebook, I will try to reshape the dataset in order to be easily interpeted

# %% [markdown]
# #### importing the necessary libraries and load the dataset

# %%
import pandas as pd
import pandas as pd
import numpy as np
pd.set_option('display.width', 1000)

# %%
dataset_all = pd.read_excel("scotpho_data_extract.xlsx")

# %%
pd.set_option('display.max_colwidth', 500)

# %% [markdown]
# #### Indicators

# %%
indicator_names = dataset_all['indicator'].unique()
print('Number of Indicators: '+str(len(indicator_names)))
print('Some Indicators are described bellow')
indicator_names_df = pd.DataFrame(indicator_names, columns=['indicator'])
indicator_names_df.head()
# Out:
# Number of Indicators: 223
# Some Indicators are described bellow
#                                                                        indicator
# 0  % people perceiving rowdy behaviour very/fairly common in their neighbourhood
# 1                                                                 ABIs delivered
# 2                                                        Active travel to school
# 3                                                          Active travel to work
# 4                 Adults claiming incapacity benefit/severe disability allowance

# %% [markdown]
# #### Area Name

# %%
area_names = dataset_all['area_name'].unique()
print('Number of area names: '+str(len(area_names)))
print('Some area names are described bellow')
area_names_df = pd.DataFrame(area_names, columns=['area_name'])
area_names_df.head()
# Out:
# Number of area names: 1447
# Some area names are described bellow
# ['Area Name: Scotland' 'Area Name: Lanarkshire' 'Area Name: Borders'
#  'Area Name: Dumfries & Galloway' 'Area Name: Fife']
#              area_name
# 0             Scotland
# 1          Lanarkshire
# 2              Borders
# 3  Dumfries & Galloway
# 4                 Fife

# %% [markdown]
# #### Area Type

# %%
area_types = dataset_all['area_type'].unique()[:-1]
print('Number of area types: '+str(len(area_types)))
print(' Area types are described bellow')
area_types_df = pd.DataFrame(area_types, columns=['area_type'])
area_types_df
# Out:
# Number of area types: 7
#  Area types are described bellow
#                     area_type
# 0                    Scotland
# 1  Alcohol & drug partnership
# 2                Health board
# 3                Council area
# 4           Intermediate zone
# 5             HSC partnership
# 6                HSC locality

# %% [markdown]
# #### Area Code

# %%
area_codes = dataset_all['area_code'].unique()
print('Number of area codes: '+str(len(area_codes)))
print(' some area codes are described bellow')
area_codes_df = pd.DataFrame(area_codes, columns=['area_code'])
area_codes_df.head()
# Out:
# Number of area codes: 1518
#  some area codes are described bellow
#    area_code
# 0  S00000001
# 1  S11000052
# 2  S08000016
# 3  S08000017
# 4  S08000029

# %% [markdown]
# #### Definition

# %%
definitions = dataset_all['definition'].unique()
print('Number of definitions or metrics: '+str(len(definitions)))
print(' Definitions are described bellow')
area_definitions_df = pd.DataFrame(definitions, columns=['definition/metric'])
area_definitions_df
# Out:
# Number of definitions or metrics: 23
#  Definitions are described bellow
#                                 definition/metric
# 0                                      Percentage
# 1           Age-sex standardised rate per 100,000
# 2                Crude rate per 10,000 population
# 3                                      Crude Rate
# 4                               rate / 10,000 pop
# 5              Directly age-sex standardised rate
# 6       crude rate per 10,000 population aged <18
# 7                            Crude rate per 1,000
# 8     Crude rate per 1,000 children aged under 18
# 9   Crude rate per 1,000 children aged 0-15 years
# 10        Crude rate per 1,000 children aged 8-15
# 11                         Crude rate per 100,000
# 12                          Crude rate per 10,000
# 13            Estimated life expectancy (females)
# 14                                           Mean
# 15                Crude rate per 1000 live births
# 16              Estimated life expectancy (males)
# 17                                     Crude rate
# 18                                         Number
# 19                 Percentage of total population
# 20                       rate / 10,000 population
# 21                    Crude rate per 1,000 pupils
# 22                       Percentage with C letter

# %% [markdown]
# ## Grouping

# %%
grouped_by_indicator = dataset_all.groupby('indicator')
for indicator, indicator_df in grouped_by_indicator:
    print(indicator)
# Out:
# % people perceiving rowdy behaviour very/fairly common in their neighbourhood
# ABIs delivered
# Active travel to school
# Active travel to work
# Adults claiming incapacity benefit/severe disability allowance
# Adults rating neighbourhood as a very good place to live
# Alcohol treatment waiting times
# Alcohol-related hospital stays
# Alcohol-related hospital stays, aged 11-25 years
# Alcohol-related mortality
# All-cause mortality among the 15-44 year olds
# Annual participation measure
# Attempted murder & serious assault
# Attempts to purchase cigarettes
# Availability of smoking cessation products
# Babies exclusively breastfed at 6-8 weeks
# Bowel screening uptake
# Breach of the Peace
# Breast screening uptake
# COPD deaths
# COPD incidence
# Child dental health in primary 1
# Child dental health in primary 7
# Child healthy weight in primary 1
# Child protection with parental alcohol misuse
# Child protection with parental drug misuse
# Child protection with parental drug or alcohol misuse
# Children admitted to hospital due to asthma
# Children being offered drugs (pupils age 15)
# Children in low income families
# Children looked after by local authority
# Children on the child protection register
# Children referred to the Children's Reporter for care and protection
# Children referred to the Children's Reporter for offences
# Children registered for free school meals
# Common assault
# Crime rate
# Deaths all ages
# Deaths from suicide
# Deaths from suicide in young people
# Deaths in children aged 1-15 years
# Developmental concerns at 27-30 months
# Domestic Abuse
# Drug crimes recorded
# Drug treatment waiting times
# Drug use funded by crime
# Drug use last month (pupils age 15)
# Drug use last year (pupils age 15)
# Drug-related hospital stays
# Drug-related hospital stays, aged 11-25 years
# Drug-related mortality
# Early deaths from cancer (<75)
# Early deaths from coronary heart disease (<75)
# Employment rate for 16-24 year olds
# Exposure to secondhand smoke at 6-8 weeks
# Female alcohol-related mortality
# Female common mental health problems
# Female deaths from suicide
# Female drug-related mortality
# Female life expectancy
# Female mean life satisfaction score
# Female mean mental wellbeing score
# Female prevalence of problem drug use
# Females binge drinking
# Females exceeding weekly drinking limits
# Females problem drinking
# Healthy birth weight
# Hepatitis-C positives among PWID
# Households with children living in fuel poverty
# Households with children living in homes that fail the SHQS
# Immunisation uptake at 24 months - 5 in 1
# Immunisation uptake at 24 months - MMR
# Individuals binge drinking
# Individuals exceeding weekly drinking limits
# Individuals problem drinking
# Infant deaths
# Live births
# Looked after school leavers in positive destinations
# Looked after school leavers with 1 or more qualification at SCQF Level 4
# Lung cancer deaths
# Lung cancer registrations
# Male alcohol-related mortality
# Male common mental health problems
# Male deaths from suicide
# Male drug-related mortality
# Male life expectancy
# Male mean life satisfaction score
# Male mean mental wellbeing score
# Male prevalence of problem drug use
# Males binge drinking
# Males exceeding weekly drinking limits
# Males problem drinking
# Maternal obesity
# Maternities with drug use
# Mean mental wellbeing score for S4 pupils
# Mean total difficulties score for S4 pupils
# Mid-year population estimate - aged 0-15 years
# Mid-year population estimate - aged 0-25 years
# Mid-year population estimate - aged 1-4 years
# Mid-year population estimate - aged 16+ years
# Mid-year population estimate - aged 16-25 years
# Mid-year population estimate - aged 16-39 years
# Mid-year population estimate - aged 16-64 years
# Mid-year population estimate - aged 18+ years
# Mid-year population estimate - aged 40-64 years
# Mid-year population estimate - aged 5-15 years
# Mid-year population estimate - aged 65+ years
# Mid-year population estimate - aged 65-74 years
# Mid-year population estimate - aged 75+ years
# Mid-year population estimate - aged 85+ years
# Mid-year population estimate - aged under 1 year
# Mid-year population estimate - aged under 18 years
# Mid-year population estimate - all ages
# New cancer registrations
# Patients (65+) with multiple emergency hospitalisations
# Patients hospitalised with COPD
# Patients hospitalised with asthma
# Patients hospitalised with coronary heart disease
# Patients with a psychiatric hospitalisation
# Patients with emergency hospitalisations
# People aged 65+ with high levels of care needs who are cared for at home
# People claiming pension credits (60+)
# People living in 15% most 'access deprived' areas
# Perception of drug misuse in neighbourhood
# Personal licences in force
# Population income deprived
# Population prescribed drugs for anxiety/depression/psychosis
# Population prevalence of problem drug use
# Population within 500 metres of a derelict site
# Post-partum smoking rate
# Premature births
# Premise licences in force - Off trade
# Premise licences in force - On trade
# Premise licences in force - Total
# Primary school children
# Prisoner population
# Proportion of S4 pupils in good or excellent general health
# Proportion of S4 pupils participating in recreational groups and activities
# Proportion of S4 pupils who are regular smokers
# Proportion of S4 pupils who are weekly drinkers
# Proportion of S4 pupils who use drugs monthly
# Quit attempts
# Quit attempts from pregnant smokers
# Quit rate at 12 months follow-up
# Quit rate at 12 weeks follow-up
# Quit rate at 4 weeks follow-up
# Quit rate at 4 weeks follow-up in least deprived quintile 5
# Quit rate at 4 weeks follow-up in most deprived quintile 1
# Quit rate at 4 weeks follow-up in quintile 2
# Quit rate at 4 weeks follow-up in quintile 3
# Quit rate at 4 weeks follow-up in quintile 4
# Road traffic accident casualties
# S2 boys conduct problems percentage with a borderline/abnormal score
# S2 boys emotional and behavioural problems percentage with a borderline/abnormal score
# S2 boys emotional symptoms percentage with a borderline/abnormal score
# S2 boys hyperactive percentage with a borderline/abnormal score
# S2 boys mean mental wellbeing score
# S2 boys pro-social behaviour percentage with a borderline/abnormal score
# S2 girls conduct problems percentage with a borderline/abnormal score
# S2 girls emotional and behavioural problems percentage with a borderline/abnormal score
# S2 girls emotional symptoms percentage with a borderline/abnormal score
# S2 girls hyperactive percentage with a borderline/abnormal score
# S2 girls mean mental wellbeing score
# S2 girls pro-social behaviour percentage with a borderline/abnormal score
# S2 pupils - SALSUS
# S4 boys conduct problems percentage with a borderline/abnormal score
# S4 boys emotional and behavioural problems percentage with a borderline/abnormal score
# S4 boys emotional symptoms percentage with a borderline/abnormal score
# S4 boys hyperactive percentage with a borderline/abnormal score
# S4 boys mean mental wellbeing score
# S4 boys pro-social behaviour percentage with a borderline/abnormal score
# S4 girls conduct problems percentage with a borderline/abnormal score
# S4 girls emotional and behavioural problems percentage with a borderline/abnormal score
# S4 girls emotional symptoms percentage with a borderline/abnormal score
# S4 girls hyperactive percentage with a borderline/abnormal score
# S4 girls mean mental wellbeing score
# S4 girls pro-social behaviour percentage with a borderline/abnormal score
# S4 pupils - SALSUS
# SDMD follow-up completeness
# SDMD initial completeness
# School exclusion rate
# School leavers in positive destinations
# School leavers living in the most deprived quintile with 1 or more qualification at SCQF Level 6
# School leavers with 1 or more qualification at SCQF Level 4
# School leavers with 1 or more qualification at SCQF Level 6
# Secondary school attendance
# Secondary school attendance by looked after children
# Secondary school children
# Single adult dwellings
# Smoking attributable admissions
# Smoking attributable deaths
# Smoking during pregnancy in least deprived quintile (5)
# Smoking during pregnancy in most deprived quintile (1)
# Smoking during pregnancy in quintile 2
# Smoking during pregnancy in quintile 3
# Smoking during pregnancy in quintile 4
# Smoking prevalence (adults 16+)
# Smoking prevalence (adults 16-34)
# Smoking prevalence (adults 16-64)
# Smoking prevalence (adults 35-64)
# Smoking prevalence (adults 65+)
# Smoking prevalence (men aged 16+)
# Smoking prevalence (women aged 16+)
# Smoking prevalence in S2 and S4 boys
# Smoking prevalence in S2 and S4 girls
# Smoking prevalence in S2 pupils
# Smoking prevalence in S4 pupils
# Teenage pregnancies
# Tobacco retailers per 1,000 population
# Unintentional injuries in under 5s
# Uptake of the HPV vaccine in S3 girls
# Vandalism
# Violent crime
# Weekly drinkers (pupils age 15)
# Women smoking during pregnancy
# Working age adults with low or no educational qualifications
# Working age population claiming out-of-work benefits
# Working age population employment deprived
# Young people admitted to hospital due to assault
# Young people in prison
# Young people living in the most access deprived quintile
# Young people living in the most crime deprived quintile
# Young people living in the most income deprived quintile

# %%
grouped_by_indicator_area_type = dataset_all.groupby(['indicator','area_type'])
for pair, pair_df in grouped_by_indicator_area_type:
    print(pair)
# Out:
# ('% people perceiving rowdy behaviour very/fairly common in their neighbourhood', 'Alcohol & drug partnership')
# ('% people perceiving rowdy behaviour very/fairly common in their neighbourhood', 'Health board')
# ('% people perceiving rowdy behaviour very/fairly common in their neighbourhood', 'Scotland')
# ('ABIs delivered', 'Health board')
# ('ABIs delivered', 'Scotland')
# ('Active travel to school', 'Council area')
# ('Active travel to school', 'Health board')
# ('Active travel to school', 'Scotland')
# ('Active travel to work', 'Council area')
# ('Active travel to work', 'Health board')
# ('Active travel to work', 'Scotland')
# ('Adults claiming incapacity benefit/severe disability allowance', 'Council area')
# ('Adults claiming incapacity benefit/severe disability allowance', 'Health board')
# ('Adults claiming incapacity benefit/severe disability allowance', 'Scotland')
# ('Adults rating neighbourhood as a very good place to live', 'Council area')
# ('Adults rating neighbourhood as a very good place to live', 'Health board')
# ('Adults rating neighbourhood as a very good place to live', 'Scotland')
# ('Alcohol treatment waiting times', 'Alcohol & drug partnership')
# ('Alcohol treatment waiting times', 'Health board')
# ('Alcohol treatment waiting times', 'Scotland')
# ('Alcohol-related hospital stays', 'Alcohol & drug partnership')
# ('Alcohol-related hospital stays', 'Council area')
# ('Alcohol-related hospital stays', 'HSC locality')
# ('Alcohol-related hospital stays', 'HSC partnership')
# ('Alcohol-related hospital stays', 'Health board')
# ('Alcohol-related hospital stays', 'Intermediate zone')
# ('Alcohol-related hospital stays', 'Scotland')
# ('Alcohol-related hospital stays, aged 11-25 years', 'Council area')
# ('Alcohol-related hospital stays, aged 11-25 years', 'Health board')
# ('Alcohol-related hospital stays, aged 11-25 years', 'Scotland')
# ('Alcohol-related mortality', 'Alcohol & drug partnership')
# ('Alcohol-related mortality', 'Council area')
# ('Alcohol-related mortality', 'HSC locality')
# ('Alcohol-related mortality', 'HSC partnership')
# ('Alcohol-related mortality', 'Health board')
# ('Alcohol-related mortality', 'Scotland')
# ('All-cause mortality among the 15-44 year olds', 'Council area')
# ('All-cause mortality among the 15-44 year olds', 'HSC locality')
# ('All-cause mortality among the 15-44 year olds', 'HSC partnership')
# ('All-cause mortality among the 15-44 year olds', 'Health board')
# ('All-cause mortality among the 15-44 year olds', 'Intermediate zone')
# ('All-cause mortality among the 15-44 year olds', 'Scotland')
# ('Annual participation measure', 'Council area')
# ('Annual participation measure', 'Health board')
# ('Annual participation measure', 'Scotland')
# ('Attempted murder & serious assault', 'Alcohol & drug partnership')
# ('Attempted murder & serious assault', 'Health board')
# ('Attempted murder & serious assault', 'Scotland')
# ('Attempts to purchase cigarettes', 'Council area')
# ('Attempts to purchase cigarettes', 'Health board')
# ('Attempts to purchase cigarettes', 'Scotland')
# ('Availability of smoking cessation products', 'Council area')
# ('Availability of smoking cessation products', 'Health board')
# ('Availability of smoking cessation products', 'Scotland')
# ('Babies exclusively breastfed at 6-8 weeks', 'Council area')
# ('Babies exclusively breastfed at 6-8 weeks', 'HSC locality')
# ('Babies exclusively breastfed at 6-8 weeks', 'HSC partnership')
# ('Babies exclusively breastfed at 6-8 weeks', 'Health board')
# ('Babies exclusively breastfed at 6-8 weeks', 'Intermediate zone')
# ('Babies exclusively breastfed at 6-8 weeks', 'Scotland')
# ('Bowel screening uptake', 'Council area')
# ('Bowel screening uptake', 'HSC locality')
# ('Bowel screening uptake', 'HSC partnership')
# ('Bowel screening uptake', 'Health board')
# ('Bowel screening uptake', 'Intermediate zone')
# ('Bowel screening uptake', 'Scotland')
# ('Breach of the Peace', 'Alcohol & drug partnership')
# ('Breach of the Peace', 'Health board')
# ('Breach of the Peace', 'Scotland')
# ('Breast screening uptake', 'Council area')
# ('Breast screening uptake', 'Health board')
# ('Breast screening uptake', 'Scotland')
# ('COPD deaths', 'Council area')
# ('COPD deaths', 'Health board')
# ('COPD deaths', 'Scotland')
# ('COPD incidence', 'Council area')
# ('COPD incidence', 'Health board')
# ('COPD incidence', 'Scotland')
# ('Child dental health in primary 1', 'Council area')
# ('Child dental health in primary 1', 'HSC locality')
# ('Child dental health in primary 1', 'HSC partnership')
# ('Child dental health in primary 1', 'Health board')
# ('Child dental health in primary 1', 'Intermediate zone')
# ('Child dental health in primary 1', 'Scotland')
# ('Child dental health in primary 7', 'Council area')
# ('Child dental health in primary 7', 'HSC locality')
# ('Child dental health in primary 7', 'HSC partnership')
# ('Child dental health in primary 7', 'Health board')
# ('Child dental health in primary 7', 'Intermediate zone')
# ('Child dental health in primary 7', 'Scotland')
# ('Child healthy weight in primary 1', 'Council area')
# ('Child healthy weight in primary 1', 'HSC locality')
# ('Child healthy weight in primary 1', 'HSC partnership')
# ('Child healthy weight in primary 1', 'Health board')
# ('Child healthy weight in primary 1', 'Intermediate zone')
# ('Child healthy weight in primary 1', 'Scotland')
# ('Child protection with parental alcohol misuse', 'Alcohol & drug partnership')
# ('Child protection with parental alcohol misuse', 'Health board')
# ('Child protection with parental alcohol misuse', 'Scotland')
# ('Child protection with parental drug misuse', 'Alcohol & drug partnership')
# ('Child protection with parental drug misuse', 'Health board')
# ('Child protection with parental drug misuse', 'Scotland')
# ('Child protection with parental drug or alcohol misuse', 'Alcohol & drug partnership')
# ('Child protection with parental drug or alcohol misuse', 'Health board')
# ('Child protection with parental drug or alcohol misuse', 'Scotland')
# ('Children admitted to hospital due to asthma', 'Council area')
# ('Children admitted to hospital due to asthma', 'Health board')
# ('Children admitted to hospital due to asthma', 'Scotland')
# ('Children being offered drugs (pupils age 15)', 'Alcohol & drug partnership')
# ('Children being offered drugs (pupils age 15)', 'Health board')
# ('Children being offered drugs (pupils age 15)', 'Scotland')
# ('Children in low income families', 'Council area')
# ('Children in low income families', 'HSC locality')
# ('Children in low income families', 'HSC partnership')
# ('Children in low income families', 'Health board')
# ('Children in low income families', 'Intermediate zone')
# ('Children in low income families', 'Scotland')
# ('Children looked after by local authority', 'Council area')
# ('Children looked after by local authority', 'Health board')
# ('Children looked after by local authority', 'Scotland')
# ('Children on the child protection register', 'Council area')
# ('Children on the child protection register', 'Health board')
# ('Children on the child protection register', 'Scotland')
# ("Children referred to the Children's Reporter for care and protection", 'Council area')
# ("Children referred to the Children's Reporter for care and protection", 'Health board')
# ("Children referred to the Children's Reporter for care and protection", 'Scotland')
# ("Children referred to the Children's Reporter for offences", 'Council area')
# ("Children referred to the Children's Reporter for offences", 'Health board')
# ("Children referred to the Children's Reporter for offences", 'Scotland')
# ('Children registered for free school meals', 'Council area')
# ('Children registered for free school meals', 'Health board')
# ('Children registered for free school meals', 'Scotland')
# ('Common assault', 'Alcohol & drug partnership')
# ('Common assault', 'Health board')
# ('Common assault', 'Scotland')
# ('Crime rate', 'Council area')
# ('Crime rate', 'HSC locality')
# ('Crime rate', 'HSC partnership')
# ('Crime rate', 'Health board')
# ('Crime rate', 'Intermediate zone')
# ('Crime rate', 'Scotland')
# ('Deaths all ages', 'Council area')
# ('Deaths all ages', 'HSC locality')
# ('Deaths all ages', 'HSC partnership')
# ('Deaths all ages', 'Health board')
# ('Deaths all ages', 'Intermediate zone')
# ('Deaths all ages', 'Scotland')
# ('Deaths from suicide', 'Council area')
# ('Deaths from suicide', 'HSC locality')
# ('Deaths from suicide', 'HSC partnership')
# ('Deaths from suicide', 'Health board')
# ('Deaths from suicide', 'Scotland')
# ('Deaths from suicide in young people', 'Council area')
# ('Deaths from suicide in young people', 'Health board')
# ('Deaths from suicide in young people', 'Scotland')
# ('Deaths in children aged 1-15 years', 'Council area')
# ('Deaths in children aged 1-15 years', 'Health board')
# ('Deaths in children aged 1-15 years', 'Scotland')
# ('Developmental concerns at 27-30 months', 'Council area')
# ('Developmental concerns at 27-30 months', 'HSC locality')
# ('Developmental concerns at 27-30 months', 'HSC partnership')
# ('Developmental concerns at 27-30 months', 'Health board')
# ('Developmental concerns at 27-30 months', 'Intermediate zone')
# ('Developmental concerns at 27-30 months', 'Scotland')
# ('Domestic Abuse', 'Council area')
# ('Domestic Abuse', 'Health board')
# ('Domestic Abuse', 'Scotland')
# ('Drug crimes recorded', 'Council area')
# ('Drug crimes recorded', 'Health board')
# ('Drug crimes recorded', 'Scotland')
# ('Drug treatment waiting times', 'Alcohol & drug partnership')
# ('Drug treatment waiting times', 'Health board')
# ('Drug treatment waiting times', 'Scotland')
# ('Drug use funded by crime', 'Alcohol & drug partnership')
# ('Drug use funded by crime', 'Health board')
# ('Drug use funded by crime', 'Scotland')
# ('Drug use last month (pupils age 15)', 'Alcohol & drug partnership')
# ('Drug use last month (pupils age 15)', 'Health board')
# ('Drug use last month (pupils age 15)', 'Scotland')
# ('Drug use last year (pupils age 15)', 'Alcohol & drug partnership')
# ('Drug use last year (pupils age 15)', 'Health board')
# ('Drug use last year (pupils age 15)', 'Scotland')
# ('Drug-related hospital stays', 'Alcohol & drug partnership')
# ('Drug-related hospital stays', 'Council area')
# ('Drug-related hospital stays', 'HSC locality')
# ('Drug-related hospital stays', 'HSC partnership')
# ('Drug-related hospital stays', 'Health board')
# ('Drug-related hospital stays', 'Scotland')
# ('Drug-related hospital stays, aged 11-25 years', 'Council area')
# ('Drug-related hospital stays, aged 11-25 years', 'Health board')
# ('Drug-related hospital stays, aged 11-25 years', 'Scotland')
# ('Drug-related mortality', 'Alcohol & drug partnership')
# ('Drug-related mortality', 'Health board')
# ('Drug-related mortality', 'Scotland')
# ('Early deaths from cancer (<75)', 'Council area')
# ('Early deaths from cancer (<75)', 'HSC locality')
# ('Early deaths from cancer (<75)', 'HSC partnership')
# ('Early deaths from cancer (<75)', 'Health board')
# ('Early deaths from cancer (<75)', 'Intermediate zone')
# ('Early deaths from cancer (<75)', 'Scotland')
# ('Early deaths from coronary heart disease (<75)', 'Council area')
# ('Early deaths from coronary heart disease (<75)', 'HSC locality')
# ('Early deaths from coronary heart disease (<75)', 'HSC partnership')
# ('Early deaths from coronary heart disease (<75)', 'Health board')
# ('Early deaths from coronary heart disease (<75)', 'Intermediate zone')
# ('Early deaths from coronary heart disease (<75)', 'Scotland')
# ('Employment rate for 16-24 year olds', 'Council area')
# ('Employment rate for 16-24 year olds', 'Health board')
# ('Employment rate for 16-24 year olds', 'Scotland')
# ('Exposure to secondhand smoke at 6-8 weeks', 'Council area')
# ('Exposure to secondhand smoke at 6-8 weeks', 'Health board')
# ('Exposure to secondhand smoke at 6-8 weeks', 'Intermediate zone')
# ('Exposure to secondhand smoke at 6-8 weeks', 'Scotland')
# ('Female alcohol-related mortality', 'Council area')
# ('Female alcohol-related mortality', 'Scotland')
# ('Female common mental health problems', 'Council area')
# ('Female common mental health problems', 'Scotland')
# ('Female deaths from suicide', 'Council area')
# ('Female deaths from suicide', 'Scotland')
# ('Female drug-related mortality', 'Council area')
# ('Female drug-related mortality', 'Scotland')
# ('Female life expectancy', 'Council area')
# ('Female life expectancy', 'Health board')
# ('Female life expectancy', 'Intermediate zone')
# ('Female life expectancy', 'Scotland')
# ('Female mean life satisfaction score', 'Council area')
# ('Female mean life satisfaction score', 'Scotland')
# ('Female mean mental wellbeing score', 'Council area')
# ('Female mean mental wellbeing score', 'Scotland')
# ('Female prevalence of problem drug use', 'Alcohol & drug partnership')
# ('Female prevalence of problem drug use', 'Council area')
# ('Female prevalence of problem drug use', 'Health board')
# ('Female prevalence of problem drug use', 'Scotland')
# ('Females binge drinking', 'Health board')
# ('Females binge drinking', 'Scotland')
# ('Females exceeding weekly drinking limits', 'Health board')
# ('Females exceeding weekly drinking limits', 'Scotland')
# ('Females problem drinking', 'Council area')
# ('Females problem drinking', 'Health board')
# ('Females problem drinking', 'Scotland')
# ('Healthy birth weight', 'Council area')
# ('Healthy birth weight', 'HSC locality')
# ('Healthy birth weight', 'HSC partnership')
# ('Healthy birth weight', 'Health board')
# ('Healthy birth weight', 'Intermediate zone')
# ('Healthy birth weight', 'Scotland')
# ('Hepatitis-C positives among PWID', 'Alcohol & drug partnership')
# ('Hepatitis-C positives among PWID', 'Health board')
# ('Hepatitis-C positives among PWID', 'Scotland')
# ('Households with children living in fuel poverty', 'Council area')
# ('Households with children living in fuel poverty', 'Health board')
# ('Households with children living in fuel poverty', 'Scotland')
# ('Households with children living in homes that fail the SHQS', 'Council area')
# ('Households with children living in homes that fail the SHQS', 'Health board')
# ('Households with children living in homes that fail the SHQS', 'Scotland')
# ('Immunisation uptake at 24 months - 5 in 1', 'Council area')
# ('Immunisation uptake at 24 months - 5 in 1', 'HSC locality')
# ('Immunisation uptake at 24 months - 5 in 1', 'HSC partnership')
# ('Immunisation uptake at 24 months - 5 in 1', 'Health board')
# ('Immunisation uptake at 24 months - 5 in 1', 'Intermediate zone')
# ('Immunisation uptake at 24 months - 5 in 1', 'Scotland')
# ('Immunisation uptake at 24 months - MMR', 'Council area')
# ('Immunisation uptake at 24 months - MMR', 'HSC locality')
# ('Immunisation uptake at 24 months - MMR', 'HSC partnership')
# ('Immunisation uptake at 24 months - MMR', 'Health board')
# ('Immunisation uptake at 24 months - MMR', 'Intermediate zone')
# ('Immunisation uptake at 24 months - MMR', 'Scotland')
# ('Individuals binge drinking', 'Health board')
# ('Individuals binge drinking', 'Scotland')
# ('Individuals exceeding weekly drinking limits', 'Health board')
# ('Individuals exceeding weekly drinking limits', 'Scotland')
# ('Individuals problem drinking', 'Health board')
# ('Individuals problem drinking', 'Scotland')
# ('Infant deaths', 'Council area')
# ('Infant deaths', 'Health board')
# ('Infant deaths', 'Scotland')
# ('Live births', 'Council area')
# ('Live births', 'HSC locality')
# ('Live births', 'HSC partnership')
# ('Live births', 'Health board')
# ('Live births', 'Intermediate zone')
# ('Live births', 'Scotland')
# ('Looked after school leavers in positive destinations', 'Council area')
# ('Looked after school leavers in positive destinations', 'Health board')
# ('Looked after school leavers in positive destinations', 'Scotland')
# ('Looked after school leavers with 1 or more qualification at SCQF Level 4', 'Council area')
# ('Looked after school leavers with 1 or more qualification at SCQF Level 4', 'Health board')
# ('Looked after school leavers with 1 or more qualification at SCQF Level 4', 'Scotland')
# ('Lung cancer deaths', 'Council area')
# ('Lung cancer deaths', 'Health board')
# ('Lung cancer deaths', 'Scotland')
# ('Lung cancer registrations', 'Council area')
# ('Lung cancer registrations', 'Health board')
# ('Lung cancer registrations', 'Scotland')
# ('Male alcohol-related mortality', 'Council area')
# ('Male alcohol-related mortality', 'Scotland')
# ('Male common mental health problems', 'Council area')
# ('Male common mental health problems', 'Scotland')
# ('Male deaths from suicide', 'Council area')
# ('Male deaths from suicide', 'Scotland')
# ('Male drug-related mortality', 'Council area')
# ('Male drug-related mortality', 'Scotland')
# ('Male life expectancy', 'Council area')
# ('Male life expectancy', 'Health board')
# ('Male life expectancy', 'Intermediate zone')
# ('Male life expectancy', 'Scotland')
# ('Male mean life satisfaction score', 'Council area')
# ('Male mean life satisfaction score', 'Scotland')
# ('Male mean mental wellbeing score', 'Council area')
# ('Male mean mental wellbeing score', 'Scotland')
# ('Male prevalence of problem drug use', 'Alcohol & drug partnership')
# ('Male prevalence of problem drug use', 'Council area')
# ('Male prevalence of problem drug use', 'Health board')
# ('Male prevalence of problem drug use', 'Scotland')
# ('Males binge drinking', 'Health board')
# ('Males binge drinking', 'Scotland')
# ('Males exceeding weekly drinking limits', 'Health board')
# ('Males exceeding weekly drinking limits', 'Scotland')
# ('Males problem drinking', 'Council area')
# ('Males problem drinking', 'Health board')
# ('Males problem drinking', 'Scotland')
# ('Maternal obesity', 'Council area')
# ('Maternal obesity', 'HSC locality')
# ('Maternal obesity', 'HSC partnership')
# ('Maternal obesity', 'Health board')
# ('Maternal obesity', 'Intermediate zone')
# ('Maternal obesity', 'Scotland')
# ('Maternities with drug use', 'Alcohol & drug partnership')
# ('Maternities with drug use', 'Health board')
# ('Maternities with drug use', 'Scotland')
# ('Mean mental wellbeing score for S4 pupils', 'Council area')
# ('Mean mental wellbeing score for S4 pupils', 'Health board')
# ('Mean mental wellbeing score for S4 pupils', 'Scotland')
# ('Mean total difficulties score for S4 pupils', 'Council area')
# ('Mean total difficulties score for S4 pupils', 'Health board')
# ('Mean total difficulties score for S4 pupils', 'Scotland')
# ('Mid-year population estimate - aged 0-15 years', 'Council area')
# ('Mid-year population estimate - aged 0-15 years', 'HSC locality')
# ('Mid-year population estimate - aged 0-15 years', 'HSC partnership')
# ('Mid-year population estimate - aged 0-15 years', 'Health board')
# ('Mid-year population estimate - aged 0-15 years', 'Intermediate zone')
# ('Mid-year population estimate - aged 0-15 years', 'Scotland')
# ('Mid-year population estimate - aged 0-25 years', 'Council area')
# ('Mid-year population estimate - aged 0-25 years', 'HSC locality')
# ('Mid-year population estimate - aged 0-25 years', 'HSC partnership')
# ('Mid-year population estimate - aged 0-25 years', 'Health board')
# ('Mid-year population estimate - aged 0-25 years', 'Intermediate zone')
# ('Mid-year population estimate - aged 0-25 years', 'Scotland')
# ('Mid-year population estimate - aged 1-4 years', 'Council area')
# ('Mid-year population estimate - aged 1-4 years', 'HSC locality')
# ('Mid-year population estimate - aged 1-4 years', 'HSC partnership')
# ('Mid-year population estimate - aged 1-4 years', 'Health board')
# ('Mid-year population estimate - aged 1-4 years', 'Intermediate zone')
# ('Mid-year population estimate - aged 1-4 years', 'Scotland')
# ('Mid-year population estimate - aged 16+ years', 'Council area')
# ('Mid-year population estimate - aged 16+ years', 'HSC locality')
# ('Mid-year population estimate - aged 16+ years', 'HSC partnership')
# ('Mid-year population estimate - aged 16+ years', 'Health board')
# ('Mid-year population estimate - aged 16+ years', 'Intermediate zone')
# ('Mid-year population estimate - aged 16+ years', 'Scotland')
# ('Mid-year population estimate - aged 16-25 years', 'Council area')
# ('Mid-year population estimate - aged 16-25 years', 'HSC locality')
# ('Mid-year population estimate - aged 16-25 years', 'HSC partnership')
# ('Mid-year population estimate - aged 16-25 years', 'Health board')
# ('Mid-year population estimate - aged 16-25 years', 'Intermediate zone')
# ('Mid-year population estimate - aged 16-25 years', 'Scotland')
# ('Mid-year population estimate - aged 16-39 years', 'Council area')
# ('Mid-year population estimate - aged 16-39 years', 'Health board')
# ('Mid-year population estimate - aged 16-39 years', 'Scotland')
# ('Mid-year population estimate - aged 16-64 years', 'Council area')
# ('Mid-year population estimate - aged 16-64 years', 'HSC locality')
# ('Mid-year population estimate - aged 16-64 years', 'HSC partnership')
# ('Mid-year population estimate - aged 16-64 years', 'Health board')
# ('Mid-year population estimate - aged 16-64 years', 'Intermediate zone')
# ('Mid-year population estimate - aged 16-64 years', 'Scotland')
# ('Mid-year population estimate - aged 18+ years', 'Alcohol & drug partnership')
# ('Mid-year population estimate - aged 18+ years', 'Health board')
# ('Mid-year population estimate - aged 18+ years', 'Scotland')
# ('Mid-year population estimate - aged 40-64 years', 'Council area')
# ('Mid-year population estimate - aged 40-64 years', 'Health board')
# ('Mid-year population estimate - aged 40-64 years', 'Scotland')
# ('Mid-year population estimate - aged 5-15 years', 'Council area')
# ('Mid-year population estimate - aged 5-15 years', 'HSC locality')
# ('Mid-year population estimate - aged 5-15 years', 'HSC partnership')
# ('Mid-year population estimate - aged 5-15 years', 'Health board')
# ('Mid-year population estimate - aged 5-15 years', 'Intermediate zone')
# ('Mid-year population estimate - aged 5-15 years', 'Scotland')
# ('Mid-year population estimate - aged 65+ years', 'Council area')
# ('Mid-year population estimate - aged 65+ years', 'Health board')
# ('Mid-year population estimate - aged 65+ years', 'Scotland')
# ('Mid-year population estimate - aged 65-74 years', 'Council area')
# ('Mid-year population estimate - aged 65-74 years', 'HSC locality')
# ('Mid-year population estimate - aged 65-74 years', 'HSC partnership')
# ('Mid-year population estimate - aged 65-74 years', 'Health board')
# ('Mid-year population estimate - aged 65-74 years', 'Intermediate zone')
# ('Mid-year population estimate - aged 65-74 years', 'Scotland')
# ('Mid-year population estimate - aged 75+ years', 'Council area')
# ('Mid-year population estimate - aged 75+ years', 'HSC locality')
# ('Mid-year population estimate - aged 75+ years', 'HSC partnership')
# ('Mid-year population estimate - aged 75+ years', 'Health board')
# ('Mid-year population estimate - aged 75+ years', 'Intermediate zone')
# ('Mid-year population estimate - aged 75+ years', 'Scotland')
# ('Mid-year population estimate - aged 85+ years', 'Council area')
# ('Mid-year population estimate - aged 85+ years', 'HSC locality')
# ('Mid-year population estimate - aged 85+ years', 'HSC partnership')
# ('Mid-year population estimate - aged 85+ years', 'Health board')
# ('Mid-year population estimate - aged 85+ years', 'Intermediate zone')
# ('Mid-year population estimate - aged 85+ years', 'Scotland')
# ('Mid-year population estimate - aged under 1 year', 'Council area')
# ('Mid-year population estimate - aged under 1 year', 'HSC locality')
# ('Mid-year population estimate - aged under 1 year', 'HSC partnership')
# ('Mid-year population estimate - aged under 1 year', 'Health board')
# ('Mid-year population estimate - aged under 1 year', 'Intermediate zone')
# ('Mid-year population estimate - aged under 1 year', 'Scotland')
# ('Mid-year population estimate - aged under 18 years', 'Alcohol & drug partnership')
# ('Mid-year population estimate - aged under 18 years', 'Health board')
# ('Mid-year population estimate - aged under 18 years', 'Scotland')
# ('Mid-year population estimate - all ages', 'Alcohol & drug partnership')
# ('Mid-year population estimate - all ages', 'Council area')
# ('Mid-year population estimate - all ages', 'HSC locality')
# ('Mid-year population estimate - all ages', 'HSC partnership')
# ('Mid-year population estimate - all ages', 'Health board')
# ('Mid-year population estimate - all ages', 'Intermediate zone')
# ('Mid-year population estimate - all ages', 'Scotland')
# ('New cancer registrations', 'Council area')
# ('New cancer registrations', 'HSC locality')
# ('New cancer registrations', 'HSC partnership')
# ('New cancer registrations', 'Health board')
# ('New cancer registrations', 'Scotland')
# ('Patients (65+) with multiple emergency hospitalisations', 'Council area')
# ('Patients (65+) with multiple emergency hospitalisations', 'HSC locality')
# ('Patients (65+) with multiple emergency hospitalisations', 'HSC partnership')
# ('Patients (65+) with multiple emergency hospitalisations', 'Health board')
# ('Patients (65+) with multiple emergency hospitalisations', 'Intermediate zone')
# ('Patients (65+) with multiple emergency hospitalisations', 'Scotland')
# ('Patients hospitalised with COPD', 'Council area')
# ('Patients hospitalised with COPD', 'HSC locality')
# ('Patients hospitalised with COPD', 'HSC partnership')
# ('Patients hospitalised with COPD', 'Health board')
# ('Patients hospitalised with COPD', 'Intermediate zone')
# ('Patients hospitalised with COPD', 'Scotland')
# ('Patients hospitalised with asthma', 'Council area')
# ('Patients hospitalised with asthma', 'HSC locality')
# ('Patients hospitalised with asthma', 'HSC partnership')
# ('Patients hospitalised with asthma', 'Health board')
# ('Patients hospitalised with asthma', 'Intermediate zone')
# ('Patients hospitalised with asthma', 'Scotland')
# ('Patients hospitalised with coronary heart disease', 'Council area')
# ('Patients hospitalised with coronary heart disease', 'HSC locality')
# ('Patients hospitalised with coronary heart disease', 'HSC partnership')
# ('Patients hospitalised with coronary heart disease', 'Health board')
# ('Patients hospitalised with coronary heart disease', 'Intermediate zone')
# ('Patients hospitalised with coronary heart disease', 'Scotland')
# ('Patients with a psychiatric hospitalisation', 'Council area')
# ('Patients with a psychiatric hospitalisation', 'HSC locality')
# ('Patients with a psychiatric hospitalisation', 'HSC partnership')
# ('Patients with a psychiatric hospitalisation', 'Health board')
# ('Patients with a psychiatric hospitalisation', 'Scotland')
# ('Patients with emergency hospitalisations', 'Council area')
# ('Patients with emergency hospitalisations', 'HSC locality')
# ('Patients with emergency hospitalisations', 'HSC partnership')
# ('Patients with emergency hospitalisations', 'Health board')
# ('Patients with emergency hospitalisations', 'Intermediate zone')
# ('Patients with emergency hospitalisations', 'Scotland')
# ('People aged 65+ with high levels of care needs who are cared for at home', 'Council area')
# ('People aged 65+ with high levels of care needs who are cared for at home', 'Health board')
# ('People aged 65+ with high levels of care needs who are cared for at home', 'Scotland')
# ('People claiming pension credits (60+)', 'Council area')
# ('People claiming pension credits (60+)', 'Health board')
# ('People claiming pension credits (60+)', 'Scotland')
# ("People living in 15% most 'access deprived' areas", 'Council area')
# ("People living in 15% most 'access deprived' areas", 'HSC locality')
# ("People living in 15% most 'access deprived' areas", 'HSC partnership')
# ("People living in 15% most 'access deprived' areas", 'Health board')
# ("People living in 15% most 'access deprived' areas", 'Intermediate zone')
# ("People living in 15% most 'access deprived' areas", 'Scotland')
# ('Perception of drug misuse in neighbourhood', 'Alcohol & drug partnership')
# ('Perception of drug misuse in neighbourhood', 'Health board')
# ('Perception of drug misuse in neighbourhood', 'Scotland')
# ('Personal licences in force', 'Alcohol & drug partnership')
# ('Personal licences in force', 'Health board')
# ('Personal licences in force', 'Scotland')
# ('Population income deprived', 'Council area')
# ('Population income deprived', 'HSC locality')
# ('Population income deprived', 'HSC partnership')
# ('Population income deprived', 'Health board')
# ('Population income deprived', 'Intermediate zone')
# ('Population income deprived', 'Scotland')
# ('Population prescribed drugs for anxiety/depression/psychosis', 'Council area')
# ('Population prescribed drugs for anxiety/depression/psychosis', 'HSC locality')
# ('Population prescribed drugs for anxiety/depression/psychosis', 'HSC partnership')
# ('Population prescribed drugs for anxiety/depression/psychosis', 'Health board')
# ('Population prescribed drugs for anxiety/depression/psychosis', 'Scotland')
# ('Population prevalence of problem drug use', 'Alcohol & drug partnership')
# ('Population prevalence of problem drug use', 'Health board')
# ('Population prevalence of problem drug use', 'Scotland')
# ('Population within 500 metres of a derelict site', 'Council area')
# ('Population within 500 metres of a derelict site', 'HSC locality')
# ('Population within 500 metres of a derelict site', 'HSC partnership')
# ('Population within 500 metres of a derelict site', 'Health board')
# ('Population within 500 metres of a derelict site', 'Intermediate zone')
# ('Population within 500 metres of a derelict site', 'Scotland')
# ('Post-partum smoking rate', 'Council area')
# ('Post-partum smoking rate', 'Health board')
# ('Post-partum smoking rate', 'Scotland')
# ('Premature births', 'Council area')
# ('Premature births', 'HSC locality')
# ('Premature births', 'HSC partnership')
# ('Premature births', 'Health board')
# ('Premature births', 'Intermediate zone')
# ('Premature births', 'Scotland')
# ('Premise licences in force - Off trade', 'Alcohol & drug partnership')
# ('Premise licences in force - Off trade', 'Health board')
# ('Premise licences in force - Off trade', 'Scotland')
# ('Premise licences in force - On trade', 'Alcohol & drug partnership')
# ('Premise licences in force - On trade', 'Health board')
# ('Premise licences in force - On trade', 'Scotland')
# ('Premise licences in force - Total', 'Alcohol & drug partnership')
# ('Premise licences in force - Total', 'Health board')
# ('Premise licences in force - Total', 'Scotland')
# ('Primary school children', 'Council area')
# ('Primary school children', 'Health board')
# ('Primary school children', 'Scotland')
# ('Prisoner population', 'Council area')
# ('Prisoner population', 'Health board')
# ('Prisoner population', 'Scotland')
# ('Proportion of S4 pupils in good or excellent general health', 'Council area')
# ('Proportion of S4 pupils in good or excellent general health', 'Health board')
# ('Proportion of S4 pupils in good or excellent general health', 'Scotland')
# ('Proportion of S4 pupils participating in recreational groups and activities', 'Council area')
# ('Proportion of S4 pupils participating in recreational groups and activities', 'Health board')
# ('Proportion of S4 pupils participating in recreational groups and activities', 'Scotland')
# ('Proportion of S4 pupils who are regular smokers', 'Council area')
# ('Proportion of S4 pupils who are regular smokers', 'Health board')
# ('Proportion of S4 pupils who are regular smokers', 'Scotland')
# ('Proportion of S4 pupils who are weekly drinkers', 'Council area')
# ('Proportion of S4 pupils who are weekly drinkers', 'Health board')
# ('Proportion of S4 pupils who are weekly drinkers', 'Scotland')
# ('Proportion of S4 pupils who use drugs monthly', 'Council area')
# ('Proportion of S4 pupils who use drugs monthly', 'Health board')
# ('Proportion of S4 pupils who use drugs monthly', 'Scotland')
# ('Quit attempts', 'Council area')
# ('Quit attempts', 'Health board')
# ('Quit attempts', 'Scotland')
# ('Quit attempts from pregnant smokers', 'Council area')
# ('Quit attempts from pregnant smokers', 'Health board')
# ('Quit attempts from pregnant smokers', 'Scotland')
# ('Quit rate at 12 months follow-up', 'Council area')
# ('Quit rate at 12 months follow-up', 'Health board')
# ('Quit rate at 12 months follow-up', 'Scotland')
# ('Quit rate at 12 weeks follow-up', 'Council area')
# ('Quit rate at 12 weeks follow-up', 'Health board')
# ('Quit rate at 12 weeks follow-up', 'Scotland')
# ('Quit rate at 4 weeks follow-up', 'Council area')
# ('Quit rate at 4 weeks follow-up', 'Health board')
# ('Quit rate at 4 weeks follow-up', 'Scotland')
# ('Quit rate at 4 weeks follow-up in least deprived quintile 5', 'Council area')
# ('Quit rate at 4 weeks follow-up in least deprived quintile 5', 'Health board')
# ('Quit rate at 4 weeks follow-up in least deprived quintile 5', 'Scotland')
# ('Quit rate at 4 weeks follow-up in most deprived quintile 1', 'Council area')
# ('Quit rate at 4 weeks follow-up in most deprived quintile 1', 'Health board')
# ('Quit rate at 4 weeks follow-up in most deprived quintile 1', 'Scotland')
# ('Quit rate at 4 weeks follow-up in quintile 2', 'Council area')
# ('Quit rate at 4 weeks follow-up in quintile 2', 'Health board')
# ('Quit rate at 4 weeks follow-up in quintile 2', 'Scotland')
# ('Quit rate at 4 weeks follow-up in quintile 3', 'Council area')
# ('Quit rate at 4 weeks follow-up in quintile 3', 'Health board')
# ('Quit rate at 4 weeks follow-up in quintile 3', 'Scotland')
# ('Quit rate at 4 weeks follow-up in quintile 4', 'Council area')
# ('Quit rate at 4 weeks follow-up in quintile 4', 'Health board')
# ('Quit rate at 4 weeks follow-up in quintile 4', 'Scotland')
# ('Road traffic accident casualties', 'Council area')
# ('Road traffic accident casualties', 'HSC locality')
# ('Road traffic accident casualties', 'HSC partnership')
# ('Road traffic accident casualties', 'Health board')
# ('Road traffic accident casualties', 'Intermediate zone')
# ('Road traffic accident casualties', 'Scotland')
# ('S2 boys conduct problems percentage with a borderline/abnormal score', 'Council area')
# ('S2 boys conduct problems percentage with a borderline/abnormal score', 'Scotland')
# ('S2 boys emotional and behavioural problems percentage with a borderline/abnormal score', 'Council area')
# ('S2 boys emotional and behavioural problems percentage with a borderline/abnormal score', 'Scotland')
# ('S2 boys emotional symptoms percentage with a borderline/abnormal score', 'Council area')
# ('S2 boys emotional symptoms percentage with a borderline/abnormal score', 'Scotland')
# ('S2 boys hyperactive percentage with a borderline/abnormal score', 'Council area')
# ('S2 boys hyperactive percentage with a borderline/abnormal score', 'Scotland')
# ('S2 boys mean mental wellbeing score', 'Council area')
# ('S2 boys mean mental wellbeing score', 'Scotland')
# ('S2 boys pro-social behaviour percentage with a borderline/abnormal score', 'Council area')
# ('S2 boys pro-social behaviour percentage with a borderline/abnormal score', 'Scotland')
# ('S2 girls conduct problems percentage with a borderline/abnormal score', 'Council area')
# ('S2 girls conduct problems percentage with a borderline/abnormal score', 'Scotland')
# ('S2 girls emotional and behavioural problems percentage with a borderline/abnormal score', 'Council area')
# ('S2 girls emotional and behavioural problems percentage with a borderline/abnormal score', 'Scotland')
# ('S2 girls emotional symptoms percentage with a borderline/abnormal score', 'Council area')
# ('S2 girls emotional symptoms percentage with a borderline/abnormal score', 'Scotland')
# ('S2 girls hyperactive percentage with a borderline/abnormal score', 'Council area')
# ('S2 girls hyperactive percentage with a borderline/abnormal score', 'Scotland')
# ('S2 girls mean mental wellbeing score', 'Council area')
# ('S2 girls mean mental wellbeing score', 'Scotland')
# ('S2 girls pro-social behaviour percentage with a borderline/abnormal score', 'Council area')
# ('S2 girls pro-social behaviour percentage with a borderline/abnormal score', 'Scotland')
# ('S2 pupils - SALSUS', 'Council area')
# ('S2 pupils - SALSUS', 'Health board')
# ('S2 pupils - SALSUS', 'Scotland')
# ('S4 boys conduct problems percentage with a borderline/abnormal score', 'Council area')
# ('S4 boys conduct problems percentage with a borderline/abnormal score', 'Scotland')
# ('S4 boys emotional and behavioural problems percentage with a borderline/abnormal score', 'Council area')
# ('S4 boys emotional and behavioural problems percentage with a borderline/abnormal score', 'Scotland')
# ('S4 boys emotional symptoms percentage with a borderline/abnormal score', 'Council area')
# ('S4 boys emotional symptoms percentage with a borderline/abnormal score', 'Scotland')
# ('S4 boys hyperactive percentage with a borderline/abnormal score', 'Council area')
# ('S4 boys hyperactive percentage with a borderline/abnormal score', 'Scotland')
# ('S4 boys mean mental wellbeing score', 'Council area')
# ('S4 boys mean mental wellbeing score', 'Scotland')
# ('S4 boys pro-social behaviour percentage with a borderline/abnormal score', 'Council area')
# ('S4 boys pro-social behaviour percentage with a borderline/abnormal score', 'Scotland')
# ('S4 girls conduct problems percentage with a borderline/abnormal score', 'Council area')
# ('S4 girls conduct problems percentage with a borderline/abnormal score', 'Scotland')
# ('S4 girls emotional and behavioural problems percentage with a borderline/abnormal score', 'Council area')
# ('S4 girls emotional and behavioural problems percentage with a borderline/abnormal score', 'Scotland')
# ('S4 girls emotional symptoms percentage with a borderline/abnormal score', 'Council area')
# ('S4 girls emotional symptoms percentage with a borderline/abnormal score', 'Scotland')
# ('S4 girls hyperactive percentage with a borderline/abnormal score', 'Council area')
# ('S4 girls hyperactive percentage with a borderline/abnormal score', 'Scotland')
# ('S4 girls mean mental wellbeing score', 'Council area')
# ('S4 girls mean mental wellbeing score', 'Scotland')
# ('S4 girls pro-social behaviour percentage with a borderline/abnormal score', 'Council area')
# ('S4 girls pro-social behaviour percentage with a borderline/abnormal score', 'Scotland')
# ('S4 pupils - SALSUS', 'Council area')
# ('S4 pupils - SALSUS', 'Health board')
# ('S4 pupils - SALSUS', 'Scotland')
# ('SDMD follow-up completeness', 'Alcohol & drug partnership')
# ('SDMD follow-up completeness', 'Health board')
# ('SDMD follow-up completeness', 'Scotland')
# ('SDMD initial completeness', 'Alcohol & drug partnership')
# ('SDMD initial completeness', 'Health board')
# ('SDMD initial completeness', 'Scotland')
# ('School exclusion rate', 'Council area')
# ('School exclusion rate', 'Health board')
# ('School exclusion rate', 'Scotland')
# ('School leavers in positive destinations', 'Council area')
# ('School leavers in positive destinations', 'Health board')
# ('School leavers in positive destinations', 'Scotland')
# ('School leavers living in the most deprived quintile with 1 or more qualification at SCQF Level 6', 'Council area')
# ('School leavers living in the most deprived quintile with 1 or more qualification at SCQF Level 6', 'Health board')
# ('School leavers living in the most deprived quintile with 1 or more qualification at SCQF Level 6', 'Scotland')
# ('School leavers with 1 or more qualification at SCQF Level 4', 'Council area')
# ('School leavers with 1 or more qualification at SCQF Level 4', 'Health board')
# ('School leavers with 1 or more qualification at SCQF Level 4', 'Scotland')
# ('School leavers with 1 or more qualification at SCQF Level 6', 'Council area')
# ('School leavers with 1 or more qualification at SCQF Level 6', 'Health board')
# ('School leavers with 1 or more qualification at SCQF Level 6', 'Scotland')
# ('Secondary school attendance', 'Council area')
# ('Secondary school attendance', 'Health board')
# ('Secondary school attendance', 'Scotland')
# ('Secondary school attendance by looked after children', 'Council area')
# ('Secondary school attendance by looked after children', 'Health board')
# ('Secondary school attendance by looked after children', 'Scotland')
# ('Secondary school children', 'Council area')
# ('Secondary school children', 'Health board')
# ('Secondary school children', 'Scotland')
# ('Single adult dwellings', 'Council area')
# ('Single adult dwellings', 'HSC locality')
# ('Single adult dwellings', 'HSC partnership')
# ('Single adult dwellings', 'Health board')
# ('Single adult dwellings', 'Intermediate zone')
# ('Single adult dwellings', 'Scotland')
# ('Smoking attributable admissions', 'Council area')
# ('Smoking attributable admissions', 'Health board')
# ('Smoking attributable admissions', 'Scotland')
# ('Smoking attributable deaths', 'Council area')
# ('Smoking attributable deaths', 'Health board')
# ('Smoking attributable deaths', 'Scotland')
# ('Smoking during pregnancy in least deprived quintile (5)', 'Council area')
# ('Smoking during pregnancy in least deprived quintile (5)', 'Health board')
# ('Smoking during pregnancy in least deprived quintile (5)', 'Scotland')
# ('Smoking during pregnancy in most deprived quintile (1)', 'Council area')
# ('Smoking during pregnancy in most deprived quintile (1)', 'Health board')
# ('Smoking during pregnancy in most deprived quintile (1)', 'Scotland')
# ('Smoking during pregnancy in quintile 2', 'Council area')
# ('Smoking during pregnancy in quintile 2', 'Health board')
# ('Smoking during pregnancy in quintile 2', 'Scotland')
# ('Smoking during pregnancy in quintile 3', 'Council area')
# ('Smoking during pregnancy in quintile 3', 'Health board')
# ('Smoking during pregnancy in quintile 3', 'Scotland')
# ('Smoking during pregnancy in quintile 4', 'Council area')
# ('Smoking during pregnancy in quintile 4', 'Health board')
# ('Smoking during pregnancy in quintile 4', 'Scotland')
# ('Smoking prevalence (adults 16+)', 'Council area')
# ('Smoking prevalence (adults 16+)', 'Health board')
# ('Smoking prevalence (adults 16+)', 'Scotland')
# ('Smoking prevalence (adults 16-34)', 'Council area')
# ('Smoking prevalence (adults 16-34)', 'Health board')
# ('Smoking prevalence (adults 16-34)', 'Scotland')
# ('Smoking prevalence (adults 16-64)', 'Council area')
# ('Smoking prevalence (adults 16-64)', 'Health board')
# ('Smoking prevalence (adults 16-64)', 'Scotland')
# ('Smoking prevalence (adults 35-64)', 'Council area')
# ('Smoking prevalence (adults 35-64)', 'Health board')
# ('Smoking prevalence (adults 35-64)', 'Scotland')
# ('Smoking prevalence (adults 65+)', 'Council area')
# ('Smoking prevalence (adults 65+)', 'Health board')
# ('Smoking prevalence (adults 65+)', 'Scotland')
# ('Smoking prevalence (men aged 16+)', 'Council area')
# ('Smoking prevalence (men aged 16+)', 'Health board')
# ('Smoking prevalence (men aged 16+)', 'Scotland')
# ('Smoking prevalence (women aged 16+)', 'Council area')
# ('Smoking prevalence (women aged 16+)', 'Health board')
# ('Smoking prevalence (women aged 16+)', 'Scotland')
# ('Smoking prevalence in S2 and S4 boys', 'Council area')
# ('Smoking prevalence in S2 and S4 boys', 'Health board')
# ('Smoking prevalence in S2 and S4 boys', 'Scotland')
# ('Smoking prevalence in S2 and S4 girls', 'Council area')
# ('Smoking prevalence in S2 and S4 girls', 'Health board')
# ('Smoking prevalence in S2 and S4 girls', 'Scotland')
# ('Smoking prevalence in S2 pupils', 'Council area')
# ('Smoking prevalence in S2 pupils', 'Health board')
# ('Smoking prevalence in S2 pupils', 'Scotland')
# ('Smoking prevalence in S4 pupils', 'Council area')
# ('Smoking prevalence in S4 pupils', 'Health board')
# ('Smoking prevalence in S4 pupils', 'Scotland')
# ('Teenage pregnancies', 'Council area')
# ('Teenage pregnancies', 'HSC locality')
# ('Teenage pregnancies', 'HSC partnership')
# ('Teenage pregnancies', 'Health board')
# ('Teenage pregnancies', 'Scotland')
# ('Tobacco retailers per 1,000 population', 'Council area')
# ('Tobacco retailers per 1,000 population', 'Health board')
# ('Tobacco retailers per 1,000 population', 'Scotland')
# ('Unintentional injuries in under 5s', 'Council area')
# ('Unintentional injuries in under 5s', 'Health board')
# ('Unintentional injuries in under 5s', 'Scotland')
# ('Uptake of the HPV vaccine in S3 girls', 'Council area')
# ('Uptake of the HPV vaccine in S3 girls', 'HSC locality')
# ('Uptake of the HPV vaccine in S3 girls', 'HSC partnership')
# ('Uptake of the HPV vaccine in S3 girls', 'Health board')
# ('Uptake of the HPV vaccine in S3 girls', 'Intermediate zone')
# ('Uptake of the HPV vaccine in S3 girls', 'Scotland')
# ('Vandalism', 'Alcohol & drug partnership')
# ('Vandalism', 'Health board')
# ('Vandalism', 'Scotland')
# ('Violent crime', 'Council area')
# ('Violent crime', 'Health board')
# ('Violent crime', 'Scotland')
# ('Weekly drinkers (pupils age 15)', 'Alcohol & drug partnership')
# ('Weekly drinkers (pupils age 15)', 'Health board')
# ('Weekly drinkers (pupils age 15)', 'Scotland')
# ('Women smoking during pregnancy', 'Council area')
# ('Women smoking during pregnancy', 'HSC locality')
# ('Women smoking during pregnancy', 'HSC partnership')
# ('Women smoking during pregnancy', 'Health board')
# ('Women smoking during pregnancy', 'Scotland')
# ('Working age adults with low or no educational qualifications', 'Council area')
# ('Working age adults with low or no educational qualifications', 'Health board')
# ('Working age adults with low or no educational qualifications', 'Scotland')
# ('Working age population claiming out-of-work benefits', 'Council area')
# ('Working age population claiming out-of-work benefits', 'Health board')
# ('Working age population claiming out-of-work benefits', 'Scotland')
# ('Working age population employment deprived', 'Council area')
# ('Working age population employment deprived', 'HSC locality')
# ('Working age population employment deprived', 'HSC partnership')
# ('Working age population employment deprived', 'Health board')
# ('Working age population employment deprived', 'Intermediate zone')
# ('Working age population employment deprived', 'Scotland')
# ('Young people admitted to hospital due to assault', 'Council area')
# ('Young people admitted to hospital due to assault', 'Health board')
# ('Young people admitted to hospital due to assault', 'Scotland')
# ('Young people in prison', 'Council area')
# ('Young people in prison', 'Health board')
# ('Young people in prison', 'Scotland')
# ('Young people living in the most access deprived quintile', 'Council area')
# ('Young people living in the most access deprived quintile', 'HSC locality')
# ('Young people living in the most access deprived quintile', 'HSC partnership')
# ('Young people living in the most access deprived quintile', 'Health board')
# ('Young people living in the most access deprived quintile', 'Intermediate zone')
# ('Young people living in the most access deprived quintile', 'Scotland')
# ('Young people living in the most crime deprived quintile', 'Council area')
# ('Young people living in the most crime deprived quintile', 'HSC locality')
# ('Young people living in the most crime deprived quintile', 'HSC partnership')
# ('Young people living in the most crime deprived quintile', 'Health board')
# ('Young people living in the most crime deprived quintile', 'Intermediate zone')
# ('Young people living in the most crime deprived quintile', 'Scotland')
# ('Young people living in the most income deprived quintile', 'Council area')
# ('Young people living in the most income deprived quintile', 'HSC locality')
# ('Young people living in the most income deprived quintile', 'HSC partnership')
# ('Young people living in the most income deprived quintile', 'Health board')
# ('Young people living in the most income deprived quintile', 'Intermediate zone')
# ('Young people living in the most income deprived quintile', 'Scotland')

# %%
grouped_by_indicator.get_group('COPD deaths')
# Out:
#          indicator                area_name  area_code     area_type  year                                          period  numerator  measure  lower_confidence_interval  upper_confidence_interval                          definition
# 39501  COPD deaths                 Scotland  S00000001      Scotland  2015  2014 to 2016 calendar years; 3-year aggregates     3093.0     77.0                       74.3                       79.9  Directly age-sex standardised rate
# 39502  COPD deaths             Glasgow City  S12000046  Council area  2015  2014 to 2016 calendar years; 3-year aggregates      424.0    119.1                      107.5                      131.6  Directly age-sex standardised rate
# 39503  COPD deaths                  Borders  S08000016  Health board  2015  2014 to 2016 calendar years; 3-year aggregates       68.0     66.7                       51.0                       85.4  Directly age-sex standardised rate
# 39504  COPD deaths      Dumfries & Galloway  S08000017  Health board  2015  2014 to 2016 calendar years; 3-year aggregates      111.0     75.8                       62.0                       91.6  Directly age-sex standardised rate
# 39505  COPD deaths                     Fife  S08000029  Health board  2015  2014 to 2016 calendar years; 3-year aggregates      213.0     72.5                       62.8                       83.3  Directly age-sex standardised rate
# 39506  COPD deaths             Forth Valley  S08000019  Health board  2015  2014 to 2016 calendar years; 3-year aggregates      188.0     87.1                       74.5                      101.2  Directly age-sex standardised rate
# 39507  COPD deaths                 Grampian  S08000020  Health board  2015  2014 to 2016 calendar years; 3-year aggregates      267.0     65.5                       57.7                       74.2  Directly age-sex standardised rate
# 39508  COPD deaths  Greater Glasgow & Clyde  S08000021  Health board  2015  2014 to 2016 calendar years; 3-year aggregates      721.0     90.7                       83.9                       97.8  Directly age-sex standardised rate
# 39509  COPD deaths                 Highland  S08000022  Health board  2015  2014 to 2016 calendar years; 3-year aggregates      151.0     54.7                       46.0                       64.5  Directly age-sex standardised rate
# 39510  COPD deaths              Lanarkshire  S08000023  Health board  2015  2014 to 2016 calendar years; 3-year aggregates      415.0     89.2                       80.4                       98.7  Directly age-sex standardised rate
# 39511  COPD deaths                  Lothian  S08000024  Health board  2015  2014 to 2016 calendar years; 3-year aggregates      401.0     70.4                       63.4                       77.9  Directly age-sex standardised rate
# 39512  COPD deaths                   Orkney  S08000025  Health board  2015  2014 to 2016 calendar years; 3-year aggregates       12.0     64.4                       31.9                      114.8  Directly age-sex standardised rate
# 39513  COPD deaths                 Shetland  S08000026  Health board  2015  2014 to 2016 calendar years; 3-year aggregates        6.0     35.7                       13.2                       76.5  Directly age-sex standardised rate
# 39514  COPD deaths                  Tayside  S08000030  Health board  2015  2014 to 2016 calendar years; 3-year aggregates      246.0     69.3                       60.7                       78.8  Directly age-sex standardised rate
# 39515  COPD deaths            Western Isles  S08000028  Health board  2015  2014 to 2016 calendar years; 3-year aggregates       16.0     62.1                       35.4                      101.0  Directly age-sex standardised rate
# 39516  COPD deaths         Clackmannanshire  S12000005  Council area  2015  2014 to 2016 calendar years; 3-year aggregates       32.0     84.8                       56.9                      121.1  Directly age-sex standardised rate
# 39517  COPD deaths      Dumfries & Galloway  S12000006  Council area  2015  2014 to 2016 calendar years; 3-year aggregates      111.0     75.8                       62.0                       91.6  Directly age-sex standardised rate
# 39518  COPD deaths            East Ayrshire  S12000008  Council area  2015  2014 to 2016 calendar years; 3-year aggregates       97.0    102.4                       82.2                      126.0  Directly age-sex standardised rate
# 39519  COPD deaths             East Lothian  S12000010  Council area  2015  2014 to 2016 calendar years; 3-year aggregates       55.0     68.0                       50.7                       89.2  Directly age-sex standardised rate
# 39520  COPD deaths        East Renfrewshire  S12000011  Council area  2015  2014 to 2016 calendar years; 3-year aggregates       34.0     46.0                       31.2                       65.2  Directly age-sex standardised rate
# 39521  COPD deaths       Na h-Eileanan Siar  S12000013  Council area  2015  2014 to 2016 calendar years; 3-year aggregates       16.0     62.1                       35.4                      101.0  Directly age-sex standardised rate
# 39522  COPD deaths                  Falkirk  S12000014  Council area  2015  2014 to 2016 calendar years; 3-year aggregates      105.0     95.8                       77.4                      117.0  Directly age-sex standardised rate
# 39523  COPD deaths                     Fife  S12000047  Council area  2015  2014 to 2016 calendar years; 3-year aggregates      213.0     72.5                       62.8                       83.3  Directly age-sex standardised rate
# 39524  COPD deaths                 Highland  S12000017  Council area  2015  2014 to 2016 calendar years; 3-year aggregates      100.0     52.0                       42.0                       63.7  Directly age-sex standardised rate
# 39525  COPD deaths               Inverclyde  S12000018  Council area  2015  2014 to 2016 calendar years; 3-year aggregates       58.0     88.9                       66.5                      116.0  Directly age-sex standardised rate
# 39526  COPD deaths               Midlothian  S12000019  Council area  2015  2014 to 2016 calendar years; 3-year aggregates       58.0     93.3                       69.7                      122.0  Directly age-sex standardised rate
# 39527  COPD deaths                    Moray  S12000020  Council area  2015  2014 to 2016 calendar years; 3-year aggregates       48.0     60.1                       43.8                       80.2  Directly age-sex standardised rate
# 39528  COPD deaths           North Ayrshire  S12000021  Council area  2015  2014 to 2016 calendar years; 3-year aggregates      103.0     92.1                       74.4                      112.5  Directly age-sex standardised rate
# 39529  COPD deaths           Orkney Islands  S12000023  Council area  2015  2014 to 2016 calendar years; 3-year aggregates       12.0     64.4                       31.9                      114.8  Directly age-sex standardised rate
# 39530  COPD deaths          Perth & Kinross  S12000048  Council area  2015  2014 to 2016 calendar years; 3-year aggregates       67.0     48.0                       36.9                       61.3  Directly age-sex standardised rate
# ...            ...                      ...        ...           ...   ...                                             ...        ...      ...                        ...                        ...                                 ...
# 40129  COPD deaths      East Dunbartonshire  S12000045  Council area  2003  2002 to 2004 calendar years; 3-year aggregates       41.0     63.4                       42.9                       89.3  Directly age-sex standardised rate
# 40130  COPD deaths             Glasgow City  S12000046  Council area  2003  2002 to 2004 calendar years; 3-year aggregates      443.0    131.0                      117.8                      145.0  Directly age-sex standardised rate
# 40131  COPD deaths                 Scotland  S00000001      Scotland  2014  2013 to 2015 calendar years; 3-year aggregates     3025.0     77.0                       74.2                       79.9  Directly age-sex standardised rate
# 40132  COPD deaths         Ayrshire & Arran  S08000015  Health board  2014  2013 to 2015 calendar years; 3-year aggregates      270.0     87.7                       77.1                       99.2  Directly age-sex standardised rate
# 40133  COPD deaths                  Borders  S08000016  Health board  2014  2013 to 2015 calendar years; 3-year aggregates       62.0     61.4                       46.4                       79.6  Directly age-sex standardised rate
# 40134  COPD deaths      Dumfries & Galloway  S08000017  Health board  2014  2013 to 2015 calendar years; 3-year aggregates      120.0     81.4                       67.2                       97.6  Directly age-sex standardised rate
# 40135  COPD deaths                     Fife  S08000029  Health board  2014  2013 to 2015 calendar years; 3-year aggregates      202.0     71.3                       61.5                       82.2  Directly age-sex standardised rate
# 40136  COPD deaths             Forth Valley  S08000019  Health board  2014  2013 to 2015 calendar years; 3-year aggregates      177.0     85.2                       72.3                       99.6  Directly age-sex standardised rate
# 40137  COPD deaths               Midlothian  S12000019  Council area  2014  2013 to 2015 calendar years; 3-year aggregates       54.0     89.0                       65.8                      117.5  Directly age-sex standardised rate
# 40138  COPD deaths                    Moray  S12000020  Council area  2014  2013 to 2015 calendar years; 3-year aggregates       46.0     60.1                       43.5                       80.8  Directly age-sex standardised rate
# 40139  COPD deaths           North Ayrshire  S12000021  Council area  2014  2013 to 2015 calendar years; 3-year aggregates      103.0     95.1                       76.6                      116.4  Directly age-sex standardised rate
# 40140  COPD deaths           Orkney Islands  S12000023  Council area  2014  2013 to 2015 calendar years; 3-year aggregates       11.0     62.6                       30.2                      113.6  Directly age-sex standardised rate
# 40141  COPD deaths          Perth & Kinross  S12000048  Council area  2014  2013 to 2015 calendar years; 3-year aggregates       71.0     53.4                       41.3                       67.9  Directly age-sex standardised rate
# 40142  COPD deaths         Scottish Borders  S12000026  Council area  2014  2013 to 2015 calendar years; 3-year aggregates       62.0     61.4                       46.4                       79.6  Directly age-sex standardised rate
# 40143  COPD deaths         Shetland Islands  S12000027  Council area  2014  2013 to 2015 calendar years; 3-year aggregates        5.0     28.4                        8.9                       66.7  Directly age-sex standardised rate
# 40144  COPD deaths           South Ayrshire  S12000028  Council area  2014  2013 to 2015 calendar years; 3-year aggregates       76.0     71.4                       55.8                       90.0  Directly age-sex standardised rate
# 40145  COPD deaths        South Lanarkshire  S12000029  Council area  2014  2013 to 2015 calendar years; 3-year aggregates      196.0     84.3                       72.2                       97.8  Directly age-sex standardised rate
# 40146  COPD deaths                 Stirling  S12000030  Council area  2014  2013 to 2015 calendar years; 3-year aggregates       45.0     68.8                       48.9                       93.6  Directly age-sex standardised rate
# 40147  COPD deaths            Aberdeen City  S12000033  Council area  2014  2013 to 2015 calendar years; 3-year aggregates      114.0     78.5                       64.2                       95.0  Directly age-sex standardised rate
# 40148  COPD deaths            Aberdeenshire  S12000034  Council area  2014  2013 to 2015 calendar years; 3-year aggregates       99.0     55.6                       45.0                       68.0  Directly age-sex standardised rate
# 40149  COPD deaths            Argyll & Bute  S12000035  Council area  2014  2013 to 2015 calendar years; 3-year aggregates       54.0     64.1                       47.5                       84.5  Directly age-sex standardised rate
# 40150  COPD deaths        City of Edinburgh  S12000036  Council area  2014  2013 to 2015 calendar years; 3-year aggregates      196.0     62.7                       53.9                       72.4  Directly age-sex standardised rate
# 40151  COPD deaths             Renfrewshire  S12000038  Council area  2014  2013 to 2015 calendar years; 3-year aggregates       89.0     67.3                       53.5                       83.4  Directly age-sex standardised rate
# 40152  COPD deaths      West Dunbartonshire  S12000039  Council area  2014  2013 to 2015 calendar years; 3-year aggregates       55.0     85.6                       63.6                      112.6  Directly age-sex standardised rate
# 40153  COPD deaths             West Lothian  S12000040  Council area  2014  2013 to 2015 calendar years; 3-year aggregates       82.0     79.1                       61.6                       99.8  Directly age-sex standardised rate
# 40154  COPD deaths                    Angus  S12000041  Council area  2014  2013 to 2015 calendar years; 3-year aggregates       69.0     67.7                       52.0                       86.4  Directly age-sex standardised rate
# 40155  COPD deaths              Dundee City  S12000042  Council area  2014  2013 to 2015 calendar years; 3-year aggregates      101.0     94.4                       76.3                      115.4  Directly age-sex standardised rate
# 40156  COPD deaths        North Lanarkshire  S12000044  Council area  2014  2013 to 2015 calendar years; 3-year aggregates      215.0     99.2                       85.5                      114.3  Directly age-sex standardised rate
# 40157  COPD deaths      East Dunbartonshire  S12000045  Council area  2014  2013 to 2015 calendar years; 3-year aggregates       41.0     42.7                       30.3                       58.4  Directly age-sex standardised rate
# 40158  COPD deaths             Glasgow City  S12000046  Council area  2014  2013 to 2015 calendar years; 3-year aggregates      432.0    121.7                      109.9                      134.4  Directly age-sex standardised rate
#
# [658 rows x 11 columns]

# %%
grouped_by_indicator_area_type = dataset_all.groupby(['indicator','area_type'])
for pair, pair_df in grouped_by_indicator_area_type:
    print(" ".join(pair))
# Out:
# % people perceiving rowdy behaviour very/fairly common in their neighbourhood Alcohol & drug partnership
# % people perceiving rowdy behaviour very/fairly common in their neighbourhood Health board
# % people perceiving rowdy behaviour very/fairly common in their neighbourhood Scotland
# ABIs delivered Health board
# ABIs delivered Scotland
# Active travel to school Council area
# Active travel to school Health board
# Active travel to school Scotland
# Active travel to work Council area
# Active travel to work Health board
# Active travel to work Scotland
# Adults claiming incapacity benefit/severe disability allowance Council area
# Adults claiming incapacity benefit/severe disability allowance Health board
# Adults claiming incapacity benefit/severe disability allowance Scotland
# Adults rating neighbourhood as a very good place to live Council area
# Adults rating neighbourhood as a very good place to live Health board
# Adults rating neighbourhood as a very good place to live Scotland
# Alcohol treatment waiting times Alcohol & drug partnership
# Alcohol treatment waiting times Health board
# Alcohol treatment waiting times Scotland
# Alcohol-related hospital stays Alcohol & drug partnership
# Alcohol-related hospital stays Council area
# Alcohol-related hospital stays HSC locality
# Alcohol-related hospital stays HSC partnership
# Alcohol-related hospital stays Health board
# Alcohol-related hospital stays Intermediate zone
# Alcohol-related hospital stays Scotland
# Alcohol-related hospital stays, aged 11-25 years Council area
# Alcohol-related hospital stays, aged 11-25 years Health board
# Alcohol-related hospital stays, aged 11-25 years Scotland
# Alcohol-related mortality Alcohol & drug partnership
# Alcohol-related mortality Council area
# Alcohol-related mortality HSC locality
# Alcohol-related mortality HSC partnership
# Alcohol-related mortality Health board
# Alcohol-related mortality Scotland
# All-cause mortality among the 15-44 year olds Council area
# All-cause mortality among the 15-44 year olds HSC locality
# All-cause mortality among the 15-44 year olds HSC partnership
# All-cause mortality among the 15-44 year olds Health board
# All-cause mortality among the 15-44 year olds Intermediate zone
# All-cause mortality among the 15-44 year olds Scotland
# Annual participation measure Council area
# Annual participation measure Health board
# Annual participation measure Scotland
# Attempted murder & serious assault Alcohol & drug partnership
# Attempted murder & serious assault Health board
# Attempted murder & serious assault Scotland
# Attempts to purchase cigarettes Council area
# Attempts to purchase cigarettes Health board
# Attempts to purchase cigarettes Scotland
# Availability of smoking cessation products Council area
# Availability of smoking cessation products Health board
# Availability of smoking cessation products Scotland
# Babies exclusively breastfed at 6-8 weeks Council area
# Babies exclusively breastfed at 6-8 weeks HSC locality
# Babies exclusively breastfed at 6-8 weeks HSC partnership
# Babies exclusively breastfed at 6-8 weeks Health board
# Babies exclusively breastfed at 6-8 weeks Intermediate zone
# Babies exclusively breastfed at 6-8 weeks Scotland
# Bowel screening uptake Council area
# Bowel screening uptake HSC locality
# Bowel screening uptake HSC partnership
# Bowel screening uptake Health board
# Bowel screening uptake Intermediate zone
# Bowel screening uptake Scotland
# Breach of the Peace Alcohol & drug partnership
# Breach of the Peace Health board
# Breach of the Peace Scotland
# Breast screening uptake Council area
# Breast screening uptake Health board
# Breast screening uptake Scotland
# COPD deaths Council area
# COPD deaths Health board
# COPD deaths Scotland
# COPD incidence Council area
# COPD incidence Health board
# COPD incidence Scotland
# Child dental health in primary 1 Council area
# Child dental health in primary 1 HSC locality
# Child dental health in primary 1 HSC partnership
# Child dental health in primary 1 Health board
# Child dental health in primary 1 Intermediate zone
# Child dental health in primary 1 Scotland
# Child dental health in primary 7 Council area
# Child dental health in primary 7 HSC locality
# Child dental health in primary 7 HSC partnership
# Child dental health in primary 7 Health board
# Child dental health in primary 7 Intermediate zone
# Child dental health in primary 7 Scotland
# Child healthy weight in primary 1 Council area
# Child healthy weight in primary 1 HSC locality
# Child healthy weight in primary 1 HSC partnership
# Child healthy weight in primary 1 Health board
# Child healthy weight in primary 1 Intermediate zone
# Child healthy weight in primary 1 Scotland
# Child protection with parental alcohol misuse Alcohol & drug partnership
# Child protection with parental alcohol misuse Health board
# Child protection with parental alcohol misuse Scotland
# Child protection with parental drug misuse Alcohol & drug partnership
# Child protection with parental drug misuse Health board
# Child protection with parental drug misuse Scotland
# Child protection with parental drug or alcohol misuse Alcohol & drug partnership
# Child protection with parental drug or alcohol misuse Health board
# Child protection with parental drug or alcohol misuse Scotland
# Children admitted to hospital due to asthma Council area
# Children admitted to hospital due to asthma Health board
# Children admitted to hospital due to asthma Scotland
# Children being offered drugs (pupils age 15) Alcohol & drug partnership
# Children being offered drugs (pupils age 15) Health board
# Children being offered drugs (pupils age 15) Scotland
# Children in low income families Council area
# Children in low income families HSC locality
# Children in low income families HSC partnership
# Children in low income families Health board
# Children in low income families Intermediate zone
# Children in low income families Scotland
# Children looked after by local authority Council area
# Children looked after by local authority Health board
# Children looked after by local authority Scotland
# Children on the child protection register Council area
# Children on the child protection register Health board
# Children on the child protection register Scotland
# Children referred to the Children's Reporter for care and protection Council area
# Children referred to the Children's Reporter for care and protection Health board
# Children referred to the Children's Reporter for care and protection Scotland
# Children referred to the Children's Reporter for offences Council area
# Children referred to the Children's Reporter for offences Health board
# Children referred to the Children's Reporter for offences Scotland
# Children registered for free school meals Council area
# Children registered for free school meals Health board
# Children registered for free school meals Scotland
# Common assault Alcohol & drug partnership
# Common assault Health board
# Common assault Scotland
# Crime rate Council area
# Crime rate HSC locality
# Crime rate HSC partnership
# Crime rate Health board
# Crime rate Intermediate zone
# Crime rate Scotland
# Deaths all ages Council area
# Deaths all ages HSC locality
# Deaths all ages HSC partnership
# Deaths all ages Health board
# Deaths all ages Intermediate zone
# Deaths all ages Scotland
# Deaths from suicide Council area
# Deaths from suicide HSC locality
# Deaths from suicide HSC partnership
# Deaths from suicide Health board
# Deaths from suicide Scotland
# Deaths from suicide in young people Council area
# Deaths from suicide in young people Health board
# Deaths from suicide in young people Scotland
# Deaths in children aged 1-15 years Council area
# Deaths in children aged 1-15 years Health board
# Deaths in children aged 1-15 years Scotland
# Developmental concerns at 27-30 months Council area
# Developmental concerns at 27-30 months HSC locality
# Developmental concerns at 27-30 months HSC partnership
# Developmental concerns at 27-30 months Health board
# Developmental concerns at 27-30 months Intermediate zone
# Developmental concerns at 27-30 months Scotland
# Domestic Abuse Council area
# Domestic Abuse Health board
# Domestic Abuse Scotland
# Drug crimes recorded Council area
# Drug crimes recorded Health board
# Drug crimes recorded Scotland
# Drug treatment waiting times Alcohol & drug partnership
# Drug treatment waiting times Health board
# Drug treatment waiting times Scotland
# Drug use funded by crime Alcohol & drug partnership
# Drug use funded by crime Health board
# Drug use funded by crime Scotland
# Drug use last month (pupils age 15) Alcohol & drug partnership
# Drug use last month (pupils age 15) Health board
# Drug use last month (pupils age 15) Scotland
# Drug use last year (pupils age 15) Alcohol & drug partnership
# Drug use last year (pupils age 15) Health board
# Drug use last year (pupils age 15) Scotland
# Drug-related hospital stays Alcohol & drug partnership
# Drug-related hospital stays Council area
# Drug-related hospital stays HSC locality
# Drug-related hospital stays HSC partnership
# Drug-related hospital stays Health board
# Drug-related hospital stays Scotland
# Drug-related hospital stays, aged 11-25 years Council area
# Drug-related hospital stays, aged 11-25 years Health board
# Drug-related hospital stays, aged 11-25 years Scotland
# Drug-related mortality Alcohol & drug partnership
# Drug-related mortality Health board
# Drug-related mortality Scotland
# Early deaths from cancer (<75) Council area
# Early deaths from cancer (<75) HSC locality
# Early deaths from cancer (<75) HSC partnership
# Early deaths from cancer (<75) Health board
# Early deaths from cancer (<75) Intermediate zone
# Early deaths from cancer (<75) Scotland
# Early deaths from coronary heart disease (<75) Council area
# Early deaths from coronary heart disease (<75) HSC locality
# Early deaths from coronary heart disease (<75) HSC partnership
# Early deaths from coronary heart disease (<75) Health board
# Early deaths from coronary heart disease (<75) Intermediate zone
# Early deaths from coronary heart disease (<75) Scotland
# Employment rate for 16-24 year olds Council area
# Employment rate for 16-24 year olds Health board
# Employment rate for 16-24 year olds Scotland
# Exposure to secondhand smoke at 6-8 weeks Council area
# Exposure to secondhand smoke at 6-8 weeks Health board
# Exposure to secondhand smoke at 6-8 weeks Intermediate zone
# Exposure to secondhand smoke at 6-8 weeks Scotland
# Female alcohol-related mortality Council area
# Female alcohol-related mortality Scotland
# Female common mental health problems Council area
# Female common mental health problems Scotland
# Female deaths from suicide Council area
# Female deaths from suicide Scotland
# Female drug-related mortality Council area
# Female drug-related mortality Scotland
# Female life expectancy Council area
# Female life expectancy Health board
# Female life expectancy Intermediate zone
# Female life expectancy Scotland
# Female mean life satisfaction score Council area
# Female mean life satisfaction score Scotland
# Female mean mental wellbeing score Council area
# Female mean mental wellbeing score Scotland
# Female prevalence of problem drug use Alcohol & drug partnership
# Female prevalence of problem drug use Council area
# Female prevalence of problem drug use Health board
# Female prevalence of problem drug use Scotland
# Females binge drinking Health board
# Females binge drinking Scotland
# Females exceeding weekly drinking limits Health board
# Females exceeding weekly drinking limits Scotland
# Females problem drinking Council area
# Females problem drinking Health board
# Females problem drinking Scotland
# Healthy birth weight Council area
# Healthy birth weight HSC locality
# Healthy birth weight HSC partnership
# Healthy birth weight Health board
# Healthy birth weight Intermediate zone
# Healthy birth weight Scotland
# Hepatitis-C positives among PWID Alcohol & drug partnership
# Hepatitis-C positives among PWID Health board
# Hepatitis-C positives among PWID Scotland
# Households with children living in fuel poverty Council area
# Households with children living in fuel poverty Health board
# Households with children living in fuel poverty Scotland
# Households with children living in homes that fail the SHQS Council area
# Households with children living in homes that fail the SHQS Health board
# Households with children living in homes that fail the SHQS Scotland
# Immunisation uptake at 24 months - 5 in 1 Council area
# Immunisation uptake at 24 months - 5 in 1 HSC locality
# Immunisation uptake at 24 months - 5 in 1 HSC partnership
# Immunisation uptake at 24 months - 5 in 1 Health board
# Immunisation uptake at 24 months - 5 in 1 Intermediate zone
# Immunisation uptake at 24 months - 5 in 1 Scotland
# Immunisation uptake at 24 months - MMR Council area
# Immunisation uptake at 24 months - MMR HSC locality
# Immunisation uptake at 24 months - MMR HSC partnership
# Immunisation uptake at 24 months - MMR Health board
# Immunisation uptake at 24 months - MMR Intermediate zone
# Immunisation uptake at 24 months - MMR Scotland
# Individuals binge drinking Health board
# Individuals binge drinking Scotland
# Individuals exceeding weekly drinking limits Health board
# Individuals exceeding weekly drinking limits Scotland
# Individuals problem drinking Health board
# Individuals problem drinking Scotland
# Infant deaths Council area
# Infant deaths Health board
# Infant deaths Scotland
# Live births Council area
# Live births HSC locality
# Live births HSC partnership
# Live births Health board
# Live births Intermediate zone
# Live births Scotland
# Looked after school leavers in positive destinations Council area
# Looked after school leavers in positive destinations Health board
# Looked after school leavers in positive destinations Scotland
# Looked after school leavers with 1 or more qualification at SCQF Level 4 Council area
# Looked after school leavers with 1 or more qualification at SCQF Level 4 Health board
# Looked after school leavers with 1 or more qualification at SCQF Level 4 Scotland
# Lung cancer deaths Council area
# Lung cancer deaths Health board
# Lung cancer deaths Scotland
# Lung cancer registrations Council area
# Lung cancer registrations Health board
# Lung cancer registrations Scotland
# Male alcohol-related mortality Council area
# Male alcohol-related mortality Scotland
# Male common mental health problems Council area
# Male common mental health problems Scotland
# Male deaths from suicide Council area
# Male deaths from suicide Scotland
# Male drug-related mortality Council area
# Male drug-related mortality Scotland
# Male life expectancy Council area
# Male life expectancy Health board
# Male life expectancy Intermediate zone
# Male life expectancy Scotland
# Male mean life satisfaction score Council area
# Male mean life satisfaction score Scotland
# Male mean mental wellbeing score Council area
# Male mean mental wellbeing score Scotland
# Male prevalence of problem drug use Alcohol & drug partnership
# Male prevalence of problem drug use Council area
# Male prevalence of problem drug use Health board
# Male prevalence of problem drug use Scotland
# Males binge drinking Health board
# Males binge drinking Scotland
# Males exceeding weekly drinking limits Health board
# Males exceeding weekly drinking limits Scotland
# Males problem drinking Council area
# Males problem drinking Health board
# Males problem drinking Scotland
# Maternal obesity Council area
# Maternal obesity HSC locality
# Maternal obesity HSC partnership
# Maternal obesity Health board
# Maternal obesity Intermediate zone
# Maternal obesity Scotland
# Maternities with drug use Alcohol & drug partnership
# Maternities with drug use Health board
# Maternities with drug use Scotland
# Mean mental wellbeing score for S4 pupils Council area
# Mean mental wellbeing score for S4 pupils Health board
# Mean mental wellbeing score for S4 pupils Scotland
# Mean total difficulties score for S4 pupils Council area
# Mean total difficulties score for S4 pupils Health board
# Mean total difficulties score for S4 pupils Scotland
# Mid-year population estimate - aged 0-15 years Council area
# Mid-year population estimate - aged 0-15 years HSC locality
# Mid-year population estimate - aged 0-15 years HSC partnership
# Mid-year population estimate - aged 0-15 years Health board
# Mid-year population estimate - aged 0-15 years Intermediate zone
# Mid-year population estimate - aged 0-15 years Scotland
# Mid-year population estimate - aged 0-25 years Council area
# Mid-year population estimate - aged 0-25 years HSC locality
# Mid-year population estimate - aged 0-25 years HSC partnership
# Mid-year population estimate - aged 0-25 years Health board
# Mid-year population estimate - aged 0-25 years Intermediate zone
# Mid-year population estimate - aged 0-25 years Scotland
# Mid-year population estimate - aged 1-4 years Council area
# Mid-year population estimate - aged 1-4 years HSC locality
# Mid-year population estimate - aged 1-4 years HSC partnership
# Mid-year population estimate - aged 1-4 years Health board
# Mid-year population estimate - aged 1-4 years Intermediate zone
# Mid-year population estimate - aged 1-4 years Scotland
# Mid-year population estimate - aged 16+ years Council area
# Mid-year population estimate - aged 16+ years HSC locality
# Mid-year population estimate - aged 16+ years HSC partnership
# Mid-year population estimate - aged 16+ years Health board
# Mid-year population estimate - aged 16+ years Intermediate zone
# Mid-year population estimate - aged 16+ years Scotland
# Mid-year population estimate - aged 16-25 years Council area
# Mid-year population estimate - aged 16-25 years HSC locality
# Mid-year population estimate - aged 16-25 years HSC partnership
# Mid-year population estimate - aged 16-25 years Health board
# Mid-year population estimate - aged 16-25 years Intermediate zone
# Mid-year population estimate - aged 16-25 years Scotland
# Mid-year population estimate - aged 16-39 years Council area
# Mid-year population estimate - aged 16-39 years Health board
# Mid-year population estimate - aged 16-39 years Scotland
# Mid-year population estimate - aged 16-64 years Council area
# Mid-year population estimate - aged 16-64 years HSC locality
# Mid-year population estimate - aged 16-64 years HSC partnership
# Mid-year population estimate - aged 16-64 years Health board
# Mid-year population estimate - aged 16-64 years Intermediate zone
# Mid-year population estimate - aged 16-64 years Scotland
# Mid-year population estimate - aged 18+ years Alcohol & drug partnership
# Mid-year population estimate - aged 18+ years Health board
# Mid-year population estimate - aged 18+ years Scotland
# Mid-year population estimate - aged 40-64 years Council area
# Mid-year population estimate - aged 40-64 years Health board
# Mid-year population estimate - aged 40-64 years Scotland
# Mid-year population estimate - aged 5-15 years Council area
# Mid-year population estimate - aged 5-15 years HSC locality
# Mid-year population estimate - aged 5-15 years HSC partnership
# Mid-year population estimate - aged 5-15 years Health board
# Mid-year population estimate - aged 5-15 years Intermediate zone
# Mid-year population estimate - aged 5-15 years Scotland
# Mid-year population estimate - aged 65+ years Council area
# Mid-year population estimate - aged 65+ years Health board
# Mid-year population estimate - aged 65+ years Scotland
# Mid-year population estimate - aged 65-74 years Council area
# Mid-year population estimate - aged 65-74 years HSC locality
# Mid-year population estimate - aged 65-74 years HSC partnership
# Mid-year population estimate - aged 65-74 years Health board
# Mid-year population estimate - aged 65-74 years Intermediate zone
# Mid-year population estimate - aged 65-74 years Scotland
# Mid-year population estimate - aged 75+ years Council area
# Mid-year population estimate - aged 75+ years HSC locality
# Mid-year population estimate - aged 75+ years HSC partnership
# Mid-year population estimate - aged 75+ years Health board
# Mid-year population estimate - aged 75+ years Intermediate zone
# Mid-year population estimate - aged 75+ years Scotland
# Mid-year population estimate - aged 85+ years Council area
# Mid-year population estimate - aged 85+ years HSC locality
# Mid-year population estimate - aged 85+ years HSC partnership
# Mid-year population estimate - aged 85+ years Health board
# Mid-year population estimate - aged 85+ years Intermediate zone
# Mid-year population estimate - aged 85+ years Scotland
# Mid-year population estimate - aged under 1 year Council area
# Mid-year population estimate - aged under 1 year HSC locality
# Mid-year population estimate - aged under 1 year HSC partnership
# Mid-year population estimate - aged under 1 year Health board
# Mid-year population estimate - aged under 1 year Intermediate zone
# Mid-year population estimate - aged under 1 year Scotland
# Mid-year population estimate - aged under 18 years Alcohol & drug partnership
# Mid-year population estimate - aged under 18 years Health board
# Mid-year population estimate - aged under 18 years Scotland
# Mid-year population estimate - all ages Alcohol & drug partnership
# Mid-year population estimate - all ages Council area
# Mid-year population estimate - all ages HSC locality
# Mid-year population estimate - all ages HSC partnership
# Mid-year population estimate - all ages Health board
# Mid-year population estimate - all ages Intermediate zone
# Mid-year population estimate - all ages Scotland
# New cancer registrations Council area
# New cancer registrations HSC locality
# New cancer registrations HSC partnership
# New cancer registrations Health board
# New cancer registrations Scotland
# Patients (65+) with multiple emergency hospitalisations Council area
# Patients (65+) with multiple emergency hospitalisations HSC locality
# Patients (65+) with multiple emergency hospitalisations HSC partnership
# Patients (65+) with multiple emergency hospitalisations Health board
# Patients (65+) with multiple emergency hospitalisations Intermediate zone
# Patients (65+) with multiple emergency hospitalisations Scotland
# Patients hospitalised with COPD Council area
# Patients hospitalised with COPD HSC locality
# Patients hospitalised with COPD HSC partnership
# Patients hospitalised with COPD Health board
# Patients hospitalised with COPD Intermediate zone
# Patients hospitalised with COPD Scotland
# Patients hospitalised with asthma Council area
# Patients hospitalised with asthma HSC locality
# Patients hospitalised with asthma HSC partnership
# Patients hospitalised with asthma Health board
# Patients hospitalised with asthma Intermediate zone
# Patients hospitalised with asthma Scotland
# Patients hospitalised with coronary heart disease Council area
# Patients hospitalised with coronary heart disease HSC locality
# Patients hospitalised with coronary heart disease HSC partnership
# Patients hospitalised with coronary heart disease Health board
# Patients hospitalised with coronary heart disease Intermediate zone
# Patients hospitalised with coronary heart disease Scotland
# Patients with a psychiatric hospitalisation Council area
# Patients with a psychiatric hospitalisation HSC locality
# Patients with a psychiatric hospitalisation HSC partnership
# Patients with a psychiatric hospitalisation Health board
# Patients with a psychiatric hospitalisation Scotland
# Patients with emergency hospitalisations Council area
# Patients with emergency hospitalisations HSC locality
# Patients with emergency hospitalisations HSC partnership
# Patients with emergency hospitalisations Health board
# Patients with emergency hospitalisations Intermediate zone
# Patients with emergency hospitalisations Scotland
# People aged 65+ with high levels of care needs who are cared for at home Council area
# People aged 65+ with high levels of care needs who are cared for at home Health board
# People aged 65+ with high levels of care needs who are cared for at home Scotland
# People claiming pension credits (60+) Council area
# People claiming pension credits (60+) Health board
# People claiming pension credits (60+) Scotland
# People living in 15% most 'access deprived' areas Council area
# People living in 15% most 'access deprived' areas HSC locality
# People living in 15% most 'access deprived' areas HSC partnership
# People living in 15% most 'access deprived' areas Health board
# People living in 15% most 'access deprived' areas Intermediate zone
# People living in 15% most 'access deprived' areas Scotland
# Perception of drug misuse in neighbourhood Alcohol & drug partnership
# Perception of drug misuse in neighbourhood Health board
# Perception of drug misuse in neighbourhood Scotland
# Personal licences in force Alcohol & drug partnership
# Personal licences in force Health board
# Personal licences in force Scotland
# Population income deprived Council area
# Population income deprived HSC locality
# Population income deprived HSC partnership
# Population income deprived Health board
# Population income deprived Intermediate zone
# Population income deprived Scotland
# Population prescribed drugs for anxiety/depression/psychosis Council area
# Population prescribed drugs for anxiety/depression/psychosis HSC locality
# Population prescribed drugs for anxiety/depression/psychosis HSC partnership
# Population prescribed drugs for anxiety/depression/psychosis Health board
# Population prescribed drugs for anxiety/depression/psychosis Scotland
# Population prevalence of problem drug use Alcohol & drug partnership
# Population prevalence of problem drug use Health board
# Population prevalence of problem drug use Scotland
# Population within 500 metres of a derelict site Council area
# Population within 500 metres of a derelict site HSC locality
# Population within 500 metres of a derelict site HSC partnership
# Population within 500 metres of a derelict site Health board
# Population within 500 metres of a derelict site Intermediate zone
# Population within 500 metres of a derelict site Scotland
# Post-partum smoking rate Council area
# Post-partum smoking rate Health board
# Post-partum smoking rate Scotland
# Premature births Council area
# Premature births HSC locality
# Premature births HSC partnership
# Premature births Health board
# Premature births Intermediate zone
# Premature births Scotland
# Premise licences in force - Off trade Alcohol & drug partnership
# Premise licences in force - Off trade Health board
# Premise licences in force - Off trade Scotland
# Premise licences in force - On trade Alcohol & drug partnership
# Premise licences in force - On trade Health board
# Premise licences in force - On trade Scotland
# Premise licences in force - Total Alcohol & drug partnership
# Premise licences in force - Total Health board
# Premise licences in force - Total Scotland
# Primary school children Council area
# Primary school children Health board
# Primary school children Scotland
# Prisoner population Council area
# Prisoner population Health board
# Prisoner population Scotland
# Proportion of S4 pupils in good or excellent general health Council area
# Proportion of S4 pupils in good or excellent general health Health board
# Proportion of S4 pupils in good or excellent general health Scotland
# Proportion of S4 pupils participating in recreational groups and activities Council area
# Proportion of S4 pupils participating in recreational groups and activities Health board
# Proportion of S4 pupils participating in recreational groups and activities Scotland
# Proportion of S4 pupils who are regular smokers Council area
# Proportion of S4 pupils who are regular smokers Health board
# Proportion of S4 pupils who are regular smokers Scotland
# Proportion of S4 pupils who are weekly drinkers Council area
# Proportion of S4 pupils who are weekly drinkers Health board
# Proportion of S4 pupils who are weekly drinkers Scotland
# Proportion of S4 pupils who use drugs monthly Council area
# Proportion of S4 pupils who use drugs monthly Health board
# Proportion of S4 pupils who use drugs monthly Scotland
# Quit attempts Council area
# Quit attempts Health board
# Quit attempts Scotland
# Quit attempts from pregnant smokers Council area
# Quit attempts from pregnant smokers Health board
# Quit attempts from pregnant smokers Scotland
# Quit rate at 12 months follow-up Council area
# Quit rate at 12 months follow-up Health board
# Quit rate at 12 months follow-up Scotland
# Quit rate at 12 weeks follow-up Council area
# Quit rate at 12 weeks follow-up Health board
# Quit rate at 12 weeks follow-up Scotland
# Quit rate at 4 weeks follow-up Council area
# Quit rate at 4 weeks follow-up Health board
# Quit rate at 4 weeks follow-up Scotland
# Quit rate at 4 weeks follow-up in least deprived quintile 5 Council area
# Quit rate at 4 weeks follow-up in least deprived quintile 5 Health board
# Quit rate at 4 weeks follow-up in least deprived quintile 5 Scotland
# Quit rate at 4 weeks follow-up in most deprived quintile 1 Council area
# Quit rate at 4 weeks follow-up in most deprived quintile 1 Health board
# Quit rate at 4 weeks follow-up in most deprived quintile 1 Scotland
# Quit rate at 4 weeks follow-up in quintile 2 Council area
# Quit rate at 4 weeks follow-up in quintile 2 Health board
# Quit rate at 4 weeks follow-up in quintile 2 Scotland
# Quit rate at 4 weeks follow-up in quintile 3 Council area
# Quit rate at 4 weeks follow-up in quintile 3 Health board
# Quit rate at 4 weeks follow-up in quintile 3 Scotland
# Quit rate at 4 weeks follow-up in quintile 4 Council area
# Quit rate at 4 weeks follow-up in quintile 4 Health board
# Quit rate at 4 weeks follow-up in quintile 4 Scotland
# Road traffic accident casualties Council area
# Road traffic accident casualties HSC locality
# Road traffic accident casualties HSC partnership
# Road traffic accident casualties Health board
# Road traffic accident casualties Intermediate zone
# Road traffic accident casualties Scotland
# S2 boys conduct problems percentage with a borderline/abnormal score Council area
# S2 boys conduct problems percentage with a borderline/abnormal score Scotland
# S2 boys emotional and behavioural problems percentage with a borderline/abnormal score Council area
# S2 boys emotional and behavioural problems percentage with a borderline/abnormal score Scotland
# S2 boys emotional symptoms percentage with a borderline/abnormal score Council area
# S2 boys emotional symptoms percentage with a borderline/abnormal score Scotland
# S2 boys hyperactive percentage with a borderline/abnormal score Council area
# S2 boys hyperactive percentage with a borderline/abnormal score Scotland
# S2 boys mean mental wellbeing score Council area
# S2 boys mean mental wellbeing score Scotland
# S2 boys pro-social behaviour percentage with a borderline/abnormal score Council area
# S2 boys pro-social behaviour percentage with a borderline/abnormal score Scotland
# S2 girls conduct problems percentage with a borderline/abnormal score Council area
# S2 girls conduct problems percentage with a borderline/abnormal score Scotland
# S2 girls emotional and behavioural problems percentage with a borderline/abnormal score Council area
# S2 girls emotional and behavioural problems percentage with a borderline/abnormal score Scotland
# S2 girls emotional symptoms percentage with a borderline/abnormal score Council area
# S2 girls emotional symptoms percentage with a borderline/abnormal score Scotland
# S2 girls hyperactive percentage with a borderline/abnormal score Council area
# S2 girls hyperactive percentage with a borderline/abnormal score Scotland
# S2 girls mean mental wellbeing score Council area
# S2 girls mean mental wellbeing score Scotland
# S2 girls pro-social behaviour percentage with a borderline/abnormal score Council area
# S2 girls pro-social behaviour percentage with a borderline/abnormal score Scotland
# S2 pupils - SALSUS Council area
# S2 pupils - SALSUS Health board
# S2 pupils - SALSUS Scotland
# S4 boys conduct problems percentage with a borderline/abnormal score Council area
# S4 boys conduct problems percentage with a borderline/abnormal score Scotland
# S4 boys emotional and behavioural problems percentage with a borderline/abnormal score Council area
# S4 boys emotional and behavioural problems percentage with a borderline/abnormal score Scotland
# S4 boys emotional symptoms percentage with a borderline/abnormal score Council area
# S4 boys emotional symptoms percentage with a borderline/abnormal score Scotland
# S4 boys hyperactive percentage with a borderline/abnormal score Council area
# S4 boys hyperactive percentage with a borderline/abnormal score Scotland
# S4 boys mean mental wellbeing score Council area
# S4 boys mean mental wellbeing score Scotland
# S4 boys pro-social behaviour percentage with a borderline/abnormal score Council area
# S4 boys pro-social behaviour percentage with a borderline/abnormal score Scotland
# S4 girls conduct problems percentage with a borderline/abnormal score Council area
# S4 girls conduct problems percentage with a borderline/abnormal score Scotland
# S4 girls emotional and behavioural problems percentage with a borderline/abnormal score Council area
# S4 girls emotional and behavioural problems percentage with a borderline/abnormal score Scotland
# S4 girls emotional symptoms percentage with a borderline/abnormal score Council area
# S4 girls emotional symptoms percentage with a borderline/abnormal score Scotland
# S4 girls hyperactive percentage with a borderline/abnormal score Council area
# S4 girls hyperactive percentage with a borderline/abnormal score Scotland
# S4 girls mean mental wellbeing score Council area
# S4 girls mean mental wellbeing score Scotland
# S4 girls pro-social behaviour percentage with a borderline/abnormal score Council area
# S4 girls pro-social behaviour percentage with a borderline/abnormal score Scotland
# S4 pupils - SALSUS Council area
# S4 pupils - SALSUS Health board
# S4 pupils - SALSUS Scotland
# SDMD follow-up completeness Alcohol & drug partnership
# SDMD follow-up completeness Health board
# SDMD follow-up completeness Scotland
# SDMD initial completeness Alcohol & drug partnership
# SDMD initial completeness Health board
# SDMD initial completeness Scotland
# School exclusion rate Council area
# School exclusion rate Health board
# School exclusion rate Scotland
# School leavers in positive destinations Council area
# School leavers in positive destinations Health board
# School leavers in positive destinations Scotland
# School leavers living in the most deprived quintile with 1 or more qualification at SCQF Level 6 Council area
# School leavers living in the most deprived quintile with 1 or more qualification at SCQF Level 6 Health board
# School leavers living in the most deprived quintile with 1 or more qualification at SCQF Level 6 Scotland
# School leavers with 1 or more qualification at SCQF Level 4 Council area
# School leavers with 1 or more qualification at SCQF Level 4 Health board
# School leavers with 1 or more qualification at SCQF Level 4 Scotland
# School leavers with 1 or more qualification at SCQF Level 6 Council area
# School leavers with 1 or more qualification at SCQF Level 6 Health board
# School leavers with 1 or more qualification at SCQF Level 6 Scotland
# Secondary school attendance Council area
# Secondary school attendance Health board
# Secondary school attendance Scotland
# Secondary school attendance by looked after children Council area
# Secondary school attendance by looked after children Health board
# Secondary school attendance by looked after children Scotland
# Secondary school children Council area
# Secondary school children Health board
# Secondary school children Scotland
# Single adult dwellings Council area
# Single adult dwellings HSC locality
# Single adult dwellings HSC partnership
# Single adult dwellings Health board
# Single adult dwellings Intermediate zone
# Single adult dwellings Scotland
# Smoking attributable admissions Council area
# Smoking attributable admissions Health board
# Smoking attributable admissions Scotland
# Smoking attributable deaths Council area
# Smoking attributable deaths Health board
# Smoking attributable deaths Scotland
# Smoking during pregnancy in least deprived quintile (5) Council area
# Smoking during pregnancy in least deprived quintile (5) Health board
# Smoking during pregnancy in least deprived quintile (5) Scotland
# Smoking during pregnancy in most deprived quintile (1) Council area
# Smoking during pregnancy in most deprived quintile (1) Health board
# Smoking during pregnancy in most deprived quintile (1) Scotland
# Smoking during pregnancy in quintile 2 Council area
# Smoking during pregnancy in quintile 2 Health board
# Smoking during pregnancy in quintile 2 Scotland
# Smoking during pregnancy in quintile 3 Council area
# Smoking during pregnancy in quintile 3 Health board
# Smoking during pregnancy in quintile 3 Scotland
# Smoking during pregnancy in quintile 4 Council area
# Smoking during pregnancy in quintile 4 Health board
# Smoking during pregnancy in quintile 4 Scotland
# Smoking prevalence (adults 16+) Council area
# Smoking prevalence (adults 16+) Health board
# Smoking prevalence (adults 16+) Scotland
# Smoking prevalence (adults 16-34) Council area
# Smoking prevalence (adults 16-34) Health board
# Smoking prevalence (adults 16-34) Scotland
# Smoking prevalence (adults 16-64) Council area
# Smoking prevalence (adults 16-64) Health board
# Smoking prevalence (adults 16-64) Scotland
# Smoking prevalence (adults 35-64) Council area
# Smoking prevalence (adults 35-64) Health board
# Smoking prevalence (adults 35-64) Scotland
# Smoking prevalence (adults 65+) Council area
# Smoking prevalence (adults 65+) Health board
# Smoking prevalence (adults 65+) Scotland
# Smoking prevalence (men aged 16+) Council area
# Smoking prevalence (men aged 16+) Health board
# Smoking prevalence (men aged 16+) Scotland
# Smoking prevalence (women aged 16+) Council area
# Smoking prevalence (women aged 16+) Health board
# Smoking prevalence (women aged 16+) Scotland
# Smoking prevalence in S2 and S4 boys Council area
# Smoking prevalence in S2 and S4 boys Health board
# Smoking prevalence in S2 and S4 boys Scotland
# Smoking prevalence in S2 and S4 girls Council area
# Smoking prevalence in S2 and S4 girls Health board
# Smoking prevalence in S2 and S4 girls Scotland
# Smoking prevalence in S2 pupils Council area
# Smoking prevalence in S2 pupils Health board
# Smoking prevalence in S2 pupils Scotland
# Smoking prevalence in S4 pupils Council area
# Smoking prevalence in S4 pupils Health board
# Smoking prevalence in S4 pupils Scotland
# Teenage pregnancies Council area
# Teenage pregnancies HSC locality
# Teenage pregnancies HSC partnership
# Teenage pregnancies Health board
# Teenage pregnancies Scotland
# Tobacco retailers per 1,000 population Council area
# Tobacco retailers per 1,000 population Health board
# Tobacco retailers per 1,000 population Scotland
# Unintentional injuries in under 5s Council area
# Unintentional injuries in under 5s Health board
# Unintentional injuries in under 5s Scotland
# Uptake of the HPV vaccine in S3 girls Council area
# Uptake of the HPV vaccine in S3 girls HSC locality
# Uptake of the HPV vaccine in S3 girls HSC partnership
# Uptake of the HPV vaccine in S3 girls Health board
# Uptake of the HPV vaccine in S3 girls Intermediate zone
# Uptake of the HPV vaccine in S3 girls Scotland
# Vandalism Alcohol & drug partnership
# Vandalism Health board
# Vandalism Scotland
# Violent crime Council area
# Violent crime Health board
# Violent crime Scotland
# Weekly drinkers (pupils age 15) Alcohol & drug partnership
# Weekly drinkers (pupils age 15) Health board
# Weekly drinkers (pupils age 15) Scotland
# Women smoking during pregnancy Council area
# Women smoking during pregnancy HSC locality
# Women smoking during pregnancy HSC partnership
# Women smoking during pregnancy Health board
# Women smoking during pregnancy Scotland
# Working age adults with low or no educational qualifications Council area
# Working age adults with low or no educational qualifications Health board
# Working age adults with low or no educational qualifications Scotland
# Working age population claiming out-of-work benefits Council area
# Working age population claiming out-of-work benefits Health board
# Working age population claiming out-of-work benefits Scotland
# Working age population employment deprived Council area
# Working age population employment deprived HSC locality
# Working age population employment deprived HSC partnership
# Working age population employment deprived Health board
# Working age population employment deprived Intermediate zone
# Working age population employment deprived Scotland
# Young people admitted to hospital due to assault Council area
# Young people admitted to hospital due to assault Health board
# Young people admitted to hospital due to assault Scotland
# Young people in prison Council area
# Young people in prison Health board
# Young people in prison Scotland
# Young people living in the most access deprived quintile Council area
# Young people living in the most access deprived quintile HSC locality
# Young people living in the most access deprived quintile HSC partnership
# Young people living in the most access deprived quintile Health board
# Young people living in the most access deprived quintile Intermediate zone
# Young people living in the most access deprived quintile Scotland
# Young people living in the most crime deprived quintile Council area
# Young people living in the most crime deprived quintile HSC locality
# Young people living in the most crime deprived quintile HSC partnership
# Young people living in the most crime deprived quintile Health board
# Young people living in the most crime deprived quintile Intermediate zone
# Young people living in the most crime deprived quintile Scotland
# Young people living in the most income deprived quintile Council area
# Young people living in the most income deprived quintile HSC locality
# Young people living in the most income deprived quintile HSC partnership
# Young people living in the most income deprived quintile Health board
# Young people living in the most income deprived quintile Intermediate zone
# Young people living in the most income deprived quintile Scotland

# %%
grouped_by_indicator_area_type.ngroups
# Out:
# 788

# %% [markdown]
# ### Representation grouped by indicator, area type, and indexed by year

# %%
#Exporting
i=2
with pd.ExcelWriter("new_representation_extract.xlsx") as writer:
    
    for pair, pair_df in grouped_by_indicator_area_type:
        df_1 =pd.DataFrame(pair_df)
        df_1.set_index('year', inplace= True)
        df_1.to_excel(writer,startrow=i)
        worksheet = writer.sheets["Sheet1"]
        worksheet.write(i-1,2," -- ".join(pair))
        i=i+df_1.shape[0]+3

# %%
df_1.shape[0]

# %% [markdown]
# ## Load only the Health Board Data for 2017

# %%
df_HB = pd.read_csv('test fo.csv')

# %%
df_HB.head()
# Out:
#                               indicator            area_name  area_code     area_type  year                  period  numerator  measure  lower_confidence_interval  upper_confidence_interval                definition
# 0  Premise licences in force - On trade     Ayrshire & Arran  S08000015  Health board  2017  2017/18 financial year      751.0    24.98                      23.22                      26.83  rate / 10,000 population
# 1  Premise licences in force - On trade              Borders  S08000016  Health board  2017  2017/18 financial year      352.0    37.63                      33.80                      41.77  rate / 10,000 population
# 2  Premise licences in force - On trade  Dumfries & Galloway  S08000017  Health board  2017  2017/18 financial year      468.0    38.14                      34.76                      41.75  rate / 10,000 population
# 3  Premise licences in force - On trade                 Fife  S08000029  Health board  2017  2017/18 financial year      693.0    23.15                      21.46                      24.94  rate / 10,000 population
# 4  Premise licences in force - On trade         Forth Valley  S08000019  Health board  2017  2017/18 financial year      585.0    23.78                      21.89                      25.79  rate / 10,000 population

# %% [markdown]
# ## Methods that will be used for the Scoring of Indicators

# %%
#this method defines if the area value is statistical different with the comparator.
# arr: measure, lower_CI, upper_CI
def is_statistical_different(vector,comparator):
    #when it is worse, means that the lower interval is greater than the measure of the comparator.
    if(vector[1]> comparator):
        return 1
    #when it better, means the the upper interval is lower than the measure of the comparator.
    if(vector[2]< comparator):
        return 1
    #else we cannot define
    return 0

#for every indicator calculates how many areas(in percentage) are statisticall significant
def score_of_statistical_different(arr, comparator):
    counter =0
    for row in arr:
        counter = counter + is_statistical_different(row, comparator)
    return counter/(arr.shape[0])

#just counts the measures that are greater than the comparator(dont know if that's correct in terms of statistics)
def is_better_for_measure_without_cf(arr,comparator):
    return (np.sum(arr[:,0]>comparator))/(arr.shape[0])
def is_worse_for_measure_without_cf(arr,comparator):
    return (np.sum(arr[:,0]<comparator))/(arr.shape[0])
#better

def is_better(vector,comparator):
    if(vector[2]< comparator):
        return 1
    return 0
    
def is_worse(vector,comparator):
    if(vector[1]> comparator):
        return 1
    return 0

#score in detail
def score_of_statistical_different_detail(arr, comparator):
    counter_better=0
    counter_worse=0
    counter=0
    arr_len = arr.shape[0]
    for row in arr:
        #counter = counter + is_better(row, comparator) + is_worse(row, comparator)
        counter_better = counter_better + is_better(row, comparator)
        counter_worse = counter_worse + is_worse(row,comparator)
        
    #scores[general,better,worse, not difference]
    counter = counter_better + counter_worse
    scores = [counter/arr_len, counter_better/arr_len, counter_worse/arr_len, 1 - (counter/arr_len)]
    return scores

# %%
#group the data of the healthboard 2017 by indicator
#Calculate the score of statisticall difference.
df_HB_ind = df_HB.groupby('indicator')
df_HB_ind.ngroups

for pair, pair_df in df_HB_ind:
    print(pair)
    #we remove Scotland's value
    train_data = (pair_df.iloc[:-1,7:10].to_numpy())

    a=pair_df.loc[pair_df['area_name'] == 'Scotland']['measure'].item()
    if(not np.isnan(train_data).any()):
        print(score_of_statistical_different(train_data,a))
        print(score_of_statistical_different_detail(train_data,a))
    else:
        print(is_better_for_measure_without_cf(train_data,a))
        print(is_worse_for_measure_without_cf(train_data,a))
    break
# Out:
# % people perceiving rowdy behaviour very/fairly common in their neighbourhood
# 0.6428571428571429
# <class 'list'>
# [0.6428571428571429, 0.5, 0.14285714285714285, 0.3571428571428571]

# %% [markdown]
# ##  Generalise for each geographic level

# %%
# Convert Jupyter Notebook to python file.

#!jupyter nbconvert --to script Dataset_Exploration_v1.ipynb
# Out:
# This application is used to convert notebook files (*.ipynb) to various other
# formats.
#
# WARNING: THE COMMANDLINE INTERFACE MAY CHANGE IN FUTURE RELEASES.
#
# Options
#
# -------
#
#
#
# Arguments that take values are actually convenience aliases to full
# Configurables, whose aliases are listed on the help line. For more information
# on full configurables, see '--help-all'.
#
#
# --debug
#
#     set log level to logging.DEBUG (maximize logging output)
#
# --generate-config
#
#     generate default config file
#
# -y
#
#     Answer yes to any questions instead of prompting.
#
# --execute
#
#     Execute the notebook prior to export.
#
# --allow-errors
#
#     Continue notebook execution even if one of the cells throws an error and include the error message in the cell output (the default behaviour is to abort conversion). This flag is only relevant if '--execute' was specified, too.
#
# --stdin
#
#     read a single notebook file from stdin. Write the resulting notebook with default basename 'notebook.*'
#
# --stdout
#
#     Write notebook output to stdout instead of files.
#
# --inplace
#
#     Run nbconvert in place, overwriting the existing notebook (only
#     relevant when converting to notebook format)
#
# --clear-output
#
#     Clear output of current file and save in place,
#     overwriting the existing notebook.
#
# --no-prompt
#
#     Exclude input and output prompts from converted document.
#
# --no-input
#
#     Exclude input cells and output prompts from converted document.
#     This mode is ideal for generating code-free reports.
# --log-level=<Enum> (Application.log_level)
#
#     Default: 30
#
#     Choices: (0, 10, 20, 30, 40, 50, 'DEBUG', 'INFO', 'WARN', 'ERROR', 'CRITICAL')
#
#     Set the log level by value or name.
#
# --config=<Unicode> (JupyterApp.config_file)
#
#     Default: ''
#
#     Full path of a config file.
#
# --to=<Unicode> (NbConvertApp.export_format)
#
#     Default: 'html'
#
#     The export format to be used, either one of the built-in formats, or a
#
#     dotted object name that represents the import path for an `Exporter` class
#
# --template=<Unicode> (TemplateExporter.template_file)
#
#     Default: ''
#
#     Name of the template file to use
#
# --writer=<DottedObjectName> (NbConvertApp.writer_class)
#
#     Default: 'FilesWriter'
#
#     Writer class used to write the  results of the conversion
#
# --post=<DottedOrNone> (NbConvertApp.postprocessor_class)
#
#     Default: ''
#
#     PostProcessor class used to write the results of the conversion
#
# --output=<Unicode> (NbConvertApp.output_base)
#
#     Default: ''
#
#     overwrite base name use for output files. can only be used when converting
#
#     one notebook at a time.
#
# --output-dir=<Unicode> (FilesWriter.build_directory)
#
#     Default: ''
#
#     Directory to write output(s) to. Defaults to output to the directory of each
#
#     notebook. To recover previous default behaviour (outputting to the current
#
#     working directory) use . as the flag value.
#
# --reveal-prefix=<Unicode> (SlidesExporter.reveal_url_prefix)
#
#     Default: ''
#
#     The URL prefix for reveal.js (version 3.x). This defaults to the reveal CDN,
#
#     but can be any url pointing to a copy  of reveal.js.
#
#     For speaker notes to work, this must be a relative path to a local  copy of
#
#     reveal.js: e.g., "reveal.js".
#
#     If a relative path is given, it must be a subdirectory of the current
#
#     directory (from which the server is run).
#
#     See the usage documentation
#
#     (https://nbconvert.readthedocs.io/en/latest/usage.html#reveal-js-html-
#
#     slideshow) for more details.
#
# --nbformat=<Enum> (NotebookExporter.nbformat_version)
#
#     Default: 4
#
#     Choices: [1, 2, 3, 4]
#
#     The nbformat version to write. Use this to downgrade notebooks.
#
# To see all available configurables, use `--help-all`
#
# Examples
# --------
#
#     The simplest way to use nbconvert is
#
#     > jupyter nbconvert mynotebook.ipynb
#
#     which will convert mynotebook.ipynb to the default format (probably HTML).
#
#     You can specify the export format with `--to`.
#     Options include ['asciidoc', 'custom', 'html', 'latex', 'markdown', 'notebook', 'pdf', 'python', 'rst', 'script', 'slides']
#
#     > jupyter nbconvert --to latex mynotebook.ipynb
#
#     Both HTML and LaTeX support multiple output templates. LaTeX includes
#     'base', 'article' and 'report'.  HTML includes 'basic' and 'full'. You
#     can specify the flavor of the format used.
#
#     > jupyter nbconvert --to html --template basic mynotebook.ipynb
#
#     You can also pipe the output to stdout, rather than a file
#
#     > jupyter nbconvert mynotebook.ipynb --stdout
#
#     PDF is generated via latex
#
#     > jupyter nbconvert mynotebook.ipynb --to pdf
#
#     You can get (and serve) a Reveal.js-powered slideshow
#
#     > jupyter nbconvert myslides.ipynb --to slides --post serve
#
#     Multiple notebooks can be given at the command line in a couple of
#     different ways:
#
#     > jupyter nbconvert notebook*.ipynb
#     > jupyter nbconvert notebook1.ipynb notebook2.ipynb
#
#     or you can specify the notebooks list in a config file, containing::
#
#         c.NbConvertApp.notebooks = ["my_notebook.ipynb"]
#
#     > jupyter nbconvert --config mycfg.py
# [NbConvertApp] WARNING | pattern 'Dataset_Exploration_v1.ipynb' matched no files

# %% [markdown]
# ## We need to group firstly by indicator, then by Geography Level and Lastly By year

# %%
#Indicators, load whatever data you want, at ScotphoProfile tool Format.
dataset_all = pd.read_csv("scotpho_data_extract.csv")

#Scotland values, Load the coresponding Scotland Values, it doesnt need to be sorted
Scotland_values = pd.read_excel("Scotland_comparator.xlsx")

# %%
Scotland_values.tail()
# Out:
#                               indicator area_name  area_code area_type  year                  period  numerator  measure  lower_confidence_interval  upper_confidence_interval  definition
# 1891  Child healthy weight in primary 1  Scotland  S00000001  Scotland  2013  2013/14 financial year    42017.0     76.4                       76.2                       76.6  Percentage
# 1892  Child healthy weight in primary 1  Scotland  S00000001  Scotland  2014  2014/15 financial year    42367.0     77.1                       76.9                       77.3  Percentage
# 1893  Child healthy weight in primary 1  Scotland  S00000001  Scotland  2015  2015/16 financial year    41246.0     76.8                       76.6                       77.0  Percentage
# 1894  Child healthy weight in primary 1  Scotland  S00000001  Scotland  2016  2016/17 financial year    40029.0     76.2                       76.0                       76.4  Percentage
# 1895  Child healthy weight in primary 1  Scotland  S00000001  Scotland  2017  2017/18 financial year    40179.0     76.5                       76.3                       76.7  Percentage

# %%
dataset_all.head()
# Out:
#                                                                        indicator            area_name  area_code                   area_type  year            period  numerator  measure  lower_confidence_interval  upper_confidence_interval  definition
# 0  % people perceiving rowdy behaviour very/fairly common in their neighbourhood          Lanarkshire  S11000052  Alcohol & drug partnership  2017  2017 survey year        NaN     10.8                        8.1                       13.5  Percentage
# 1  % people perceiving rowdy behaviour very/fairly common in their neighbourhood              Borders  S08000016                Health board  2017  2017 survey year        NaN      8.6                        3.2                       13.9  Percentage
# 2  % people perceiving rowdy behaviour very/fairly common in their neighbourhood  Dumfries & Galloway  S08000017                Health board  2017  2017 survey year        NaN      5.9                        2.2                        9.6  Percentage
# 3  % people perceiving rowdy behaviour very/fairly common in their neighbourhood                 Fife  S08000029                Health board  2017  2017 survey year        NaN     13.5                        9.7                       17.3  Percentage
# 4  % people perceiving rowdy behaviour very/fairly common in their neighbourhood         Forth Valley  S08000019                Health board  2017  2017 survey year        NaN      8.2                        5.4                       10.9  Percentage

# %%
print(Scotland_values.loc[(Scotland_values['year']==2013) & ( Scotland_values['indicator'] == 'Child healthy weight in primary 1')]['measure'].item())
# Out:
# 76.4

# %%
#Search function with input indicator and year and output the comparator value (Scotland value for this Comparator)
def find_comparator(indicator, year):
    a = Scotland_values.loc[(Scotland_values['year']==year) & ( Scotland_values['indicator'] == indicator)]['measure']
    if(a.empty):
        return 0
    return a.item()

# %%
grouped_by_indicator_area_type = dataset_all.groupby(['indicator','area_type','year'])
name_list = []
values_list = []
for pair, pair_df in grouped_by_indicator_area_type:
    #pair[0] indicator name
    #pair[2] year
    comparator = (find_comparator(pair[0], pair[2]))
    #we remove Scotland's value
    train_data = (pair_df.iloc[:,7:10].to_numpy())
   
    if(not np.isnan(train_data).any()):
        stat_diff = (score_of_statistical_different(train_data,comparator))
        stat_diff_detail = (score_of_statistical_different_detail(train_data,comparator))
        #printed_dict = {'indicator': pair[0], 'year': pair[2], 'Scotland Value': comparator,"area_type": pair[1], 'Statistical Different Score':stat_diff, 'better':stat_diff_detail[1] ,'worse':stat_diff_detail[2] , 'not difference':stat_diff_detail[3] }
        values_list.append({'Scotland Value': comparator, 'Statistical Different Score':stat_diff, 'better':stat_diff_detail[1] ,'worse':stat_diff_detail[2] , 'not difference':stat_diff_detail[3]})
    else:
        better = (is_better_for_measure_without_cf(train_data,comparator))
        worse = (is_worse_for_measure_without_cf(train_data,comparator))
        printed_dict = {'indicator': pair[0], 'year': pair[2], 'Scotland Value': comparator, "area_type": pair[1], 'Statistical Different Score':'Cannot say', 'better':better ,'worse':worse , 'not difference': 'Cannot say' }
        values_list.append({'Scotland Value': comparator,  'Statistical Different Score':'Cannot say', 'better':better ,'worse':worse , 'not difference': 'Cannot say'})
    #print(printed_dict)
    name_list.append({'indicator': pair[0], 'year': pair[2],"area_type": pair[1]})

# seperate the dataframes for a feauture use (eg Numpy array for clustering)
df_name = pd.DataFrame(name_list)
df_values = pd.DataFrame(values_list)
df_name.head(20)
df_values.head(20)
nice_df = pd.concat([df_name, df_values], axis=1, sort = False)
# Out:
# C:\Users\panagn01\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:22: RuntimeWarning: invalid value encountered in greater
# C:\Users\panagn01\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:24: RuntimeWarning: invalid value encountered in less

# %%
nice_df.head(20)
# Out:
#                      area_type                                                                      indicator  year  Scotland Value Statistical Different Score    better not difference     worse
# 0   Alcohol & drug partnership  % people perceiving rowdy behaviour very/fairly common in their neighbourhood  2007            17.0                    0.566667  0.466667       0.433333  0.100000
# 1   Alcohol & drug partnership  % people perceiving rowdy behaviour very/fairly common in their neighbourhood  2009            15.0                    0.566667  0.433333       0.433333  0.133333
# 2   Alcohol & drug partnership  % people perceiving rowdy behaviour very/fairly common in their neighbourhood  2012            14.5                         0.5  0.400000            0.5  0.100000
# 3   Alcohol & drug partnership  % people perceiving rowdy behaviour very/fairly common in their neighbourhood  2013            12.6                    0.533333  0.400000       0.466667  0.133333
# 4   Alcohol & drug partnership  % people perceiving rowdy behaviour very/fairly common in their neighbourhood  2014            11.7                    0.433333  0.300000       0.566667  0.133333
# 5   Alcohol & drug partnership  % people perceiving rowdy behaviour very/fairly common in their neighbourhood  2015            10.7                    0.566667  0.400000       0.433333  0.166667
# 6   Alcohol & drug partnership  % people perceiving rowdy behaviour very/fairly common in their neighbourhood  2016            11.2                    0.466667  0.366667       0.533333  0.100000
# 7   Alcohol & drug partnership  % people perceiving rowdy behaviour very/fairly common in their neighbourhood  2017            11.8                    0.466667  0.366667       0.533333  0.100000
# 8                 Health board  % people perceiving rowdy behaviour very/fairly common in their neighbourhood  2007            17.0                    0.714286  0.571429       0.285714  0.142857
# 9                 Health board  % people perceiving rowdy behaviour very/fairly common in their neighbourhood  2009            15.0                    0.571429  0.500000       0.428571  0.071429
# 10                Health board  % people perceiving rowdy behaviour very/fairly common in their neighbourhood  2012            14.5                    0.571429  0.428571       0.428571  0.142857
# 11                Health board  % people perceiving rowdy behaviour very/fairly common in their neighbourhood  2013            12.6                    0.571429  0.500000       0.428571  0.071429
# 12                Health board  % people perceiving rowdy behaviour very/fairly common in their neighbourhood  2014            11.7                    0.571429  0.428571       0.428571  0.142857
# 13                Health board  % people perceiving rowdy behaviour very/fairly common in their neighbourhood  2015            10.7                         0.5  0.428571            0.5  0.071429
# 14                Health board  % people perceiving rowdy behaviour very/fairly common in their neighbourhood  2016            11.2                    0.357143  0.357143       0.642857  0.000000
# 15                Health board  % people perceiving rowdy behaviour very/fairly common in their neighbourhood  2017            11.8                    0.642857  0.500000       0.357143  0.142857
# 16                Health board                                                                 ABIs delivered  2008            60.8                  Cannot say  0.500000     Cannot say  0.500000
# 17                Health board                                                                 ABIs delivered  2009           111.9                  Cannot say  0.428571     Cannot say  0.571429
# 18                Health board                                                                 ABIs delivered  2010           176.9                  Cannot say  0.500000     Cannot say  0.500000
# 19                Health board                                                                 ABIs delivered  2011           158.9                  Cannot say  0.428571     Cannot say  0.571429

# %% [markdown]
# ## Exporting to excel

# %%
nice_df.to_excel("Indicator Scoring.xlsx")

# %% [markdown]
# ## Another Point of view Version.1.2

# %% [markdown]
# #### Usually the users are from a specific Area that they are seeking for valuable information. Let's try and group the indicators by area names

# %%
#Indicators, load whatever data you want, at ScotphoProfile tool Format.
dataset_all = pd.read_csv("scotpho_data_extract.csv")

#Scotland values, Load the coresponding Scotland Values, it doesnt need to be sorted
Scotland_values = pd.read_excel("Scotland_comparator.xlsx")

# %%
#returns the above scores for a particular area
def pick_area(df,area,year):
    df.loc[(df['area_name']==area) & ( df['year'] == year)]

# %%
def find_comparator(indicator, year):
    a = Scotland_values.loc[(Scotland_values['year']==year) & ( Scotland_values['indicator'] == indicator)]['measure']
    if(a.empty):
        return 0
    return a.item()

# %% [markdown]
# #### Decide if an indicator for a specific area name and year is different from Scotland

# %%
import numpy as np

# for each indicator
# a= [Significant, better, worse, not sure]
def is_what(comparator, lower, upper):
    if(lower > comparator):
        #significant= significant+1
        #better = better +1
        a = [1,1,0,0]
        return a
    if(upper < comparator):
        #significant = significant + 1
        #worse = worse + 1
        a = [1,0,1,0]
        return a
    #not_sure = not_sure + 1
    return [0,0,0,1]
    

#for all the area
# check the indicators
# calclulate the ratio
def score(comparator_values, lower_values, upper_values):
    a = [is_what(x,y,z) for x,y,z in zip(comparator_values,lower_values,upper_values)]
    return np.sum(np.matrix(a), axis = 0)/len(comparator_values)

# %% [markdown]
# #### Run the experiment, for 21993 groups, it will take almost 30 minutes

# %%
import time
grouped_by_indicator_area_type = dataset_all.groupby(['area_name','year'])
name_list = []
values_list = []
i=0
scores_per_area =[]
for pair, pair_df in grouped_by_indicator_area_type:
    #pair[0] indicator name
    #pair[2] year
    #print(pair)
    #print(pair_df.shape)
    start_time = time.time()
    comparators = [find_comparator(x,y) for x,y in zip(pair_df['indicator'], pair_df['year'])]
    area_score = score(comparators,pair_df['lower_confidence_interval'], pair_df['upper_confidence_interval'])
    elapsed_time = time.time() - start_time
    scores_per_area.append(area_score)
elapsed_time = time.time() - start_time
print(elapsed_time)
# Out:
# 0.031250715255737305

# %%
print(len(scores_per_area))
# Out:
# 21993

# %%
per_area = [l[0].tolist() for l in scores_per_area]

# %%
# our input is a list of list, so we need to take the value of the list.
per_area_=[]
for i in range(0,len(per_area)):
    per_area_.append(per_area[i][0])

# %%
#same as above
l = [row[0] for row in per_area]

# %%
per_area_df = pd.DataFrame(per_area_, columns = ['Significant' , 'Better', 'Worse', 'Not Sure'])

# %%
pairs=[]
for pair,b in grouped_by_indicator_area_type:
    pairs.append({'area_name': pair[0], 'year': pair[1]})

labels_df = pd.DataFrame(pairs)

# %%
labels_df.head()
# Out:
#    area_name  year
# 0  Abbeyhill  2003
# 1  Abbeyhill  2004
# 2  Abbeyhill  2005
# 3  Abbeyhill  2006
# 4  Abbeyhill  2007

# %%
per_area_df.head()
# Out:
#    Significant    Better  Worse  Not Sure
# 0     0.000000  0.000000    0.0  1.000000
# 1     0.000000  0.000000    0.0  1.000000
# 2     0.000000  0.000000    0.0  1.000000
# 3     0.166667  0.166667    0.0  0.833333
# 4     0.166667  0.166667    0.0  0.833333

# %%
Final_per_area = pd.concat([labels_df, per_area_df], axis= 1)
Final_per_area.head(20)
# Out:
#                    area_name  year  Significant    Better     Worse  Not Sure
# 0                  Abbeyhill  2003     0.000000  0.000000  0.000000  1.000000
# 1                  Abbeyhill  2004     0.000000  0.000000  0.000000  1.000000
# 2                  Abbeyhill  2005     0.000000  0.000000  0.000000  1.000000
# 3                  Abbeyhill  2006     0.166667  0.166667  0.000000  0.833333
# 4                  Abbeyhill  2007     0.166667  0.166667  0.000000  0.833333
# 5                  Abbeyhill  2008     0.166667  0.166667  0.000000  0.833333
# 6                  Abbeyhill  2009     0.428571  0.142857  0.285714  0.571429
# 7                  Abbeyhill  2010     0.250000  0.125000  0.125000  0.750000
# 8                  Abbeyhill  2011     0.555556  0.222222  0.333333  0.444444
# 9                  Abbeyhill  2012     0.410256  0.153846  0.256410  0.589744
# 10                 Abbeyhill  2013     0.333333  0.119048  0.214286  0.666667
# 11                 Abbeyhill  2014     0.354167  0.145833  0.208333  0.645833
# 12                 Abbeyhill  2015     0.416667  0.166667  0.250000  0.583333
# 13                 Abbeyhill  2016     0.409091  0.136364  0.272727  0.590909
# 14                 Abbeyhill  2017     0.769231  0.269231  0.500000  0.230769
# 15  Aberchirder & Whitehills  2003     0.000000  0.000000  0.000000  1.000000
# 16  Aberchirder & Whitehills  2004     0.000000  0.000000  0.000000  1.000000
# 17  Aberchirder & Whitehills  2005     0.000000  0.000000  0.000000  1.000000
# 18  Aberchirder & Whitehills  2006     0.000000  0.000000  0.000000  1.000000
# 19  Aberchirder & Whitehills  2007     0.000000  0.000000  0.000000  1.000000

# %% [markdown]
# ## Excel

# %%
Final_per_area.to_excel("Scoring per area.xlsx")

# %% [markdown]
# ## To do, List the important indcators

# %%
#!jupyter nbconvert --to script Dataset_Exploration_version_1.ipynb
# Out:
# [NbConvertApp] Converting notebook Dataset_Exploration_version_1.ipynb to script
# [NbConvertApp] Writing 12397 bytes to Dataset_Exploration_version_1.py

# %%
import pandas as pd
import pandas as pd
import numpy as np
pd.set_option('display.width', 1000)

# %%
#Indicators, load whatever data you want, at ScotphoProfile tool Format.
dataset_all = pd.read_csv("scotpho_data_extract.csv")

#Scotland values, Load the coresponding Scotland Values, it doesnt need to be sorted
Scotland_values = pd.read_excel("Scotland_comparator.xlsx")

# %%
def find_comparator(indicator, year):
    a = Scotland_values.loc[(Scotland_values['year']==year) & ( Scotland_values['indicator'] == indicator)]['measure']
    if(a.empty):
        return 0
    return a.item()

# %%
import numpy as np

# for each indicator
# a= [Significant, better, worse, not sure]
def is_what(comparator, lower, upper):
    if(lower > comparator):
        #significant= significant+1
        #better = better +1
        a = [1,1,0,0]
        return a
    if(upper < comparator):
        #significant = significant + 1
        #worse = worse + 1
        a = [1,0,1,0]
        return a
    #not_sure = not_sure + 1
    return [0,0,0,1]
    

#for all the area
# check the indicators
# calclulate the ratio
def score(comparator_values, lower_values, upper_values):
    a = [is_what(x,y,z) for x,y,z in zip(comparator_values,lower_values,upper_values)]
    return np.sum(np.matrix(a), axis = 0)/len(comparator_values)

# %%
#find the min distance between the comparator and the confident intervals.
def find_difference(comparator,lower, upper, measure):
    if(has_confident_intervals(lower)):
        upper_diff = abs(comparator-upper)
        lower_diff = abs(comparator-lower)
        return min(upper_diff,lower_diff)
    else:
        return abs(comparator-measure)
    


def find_differnce_all(comparator_values, lower_values, upper_values,measure):
    a = [find_difference(x,y,z,d) for x,y,z,d in zip(comparator_values,lower_values,upper_values,measure)]
    return a

def create_dictionary(arr, indicator_names, area, year, area_type, has_intervals):
    return [mini_dict(a,b,area,year,c, d) for a,b,c,d in zip(arr, indicator_names, area_type,has_intervals)]
    
    return area
def mini_dict(diff,indicator,area,year,area_type,has_intervals):
    return {'indicator': indicator, 'area': area, 'year': year, 'area_type': area_type, 'has_intervals': has_intervals,'difference': diff}

import math
def has_confident_intervals(value):
    return (np.logical_not(np.isnan(value)))
def has_intervals(arr):
    # if we have nan means that we dont have intervals.
    #np is nan return true where is NaN and False when we have intervals
    #so we use the logical not
    #as a result we have an array where it contains true at the index that we have intervals.
    return (np.logical_not(np.isnan(arr)))

# %% [markdown]
# ## Testing the functions on Healthboard 2017 dataset (check bellow for the whole dataset and                                                                                                 functions details)

# %%
df_HB = pd.read_csv('test fo.csv')
df_HB.head()
# Out:
#                               indicator            area_name  area_code     area_type  year                  period  numerator  measure  lower_confidence_interval  upper_confidence_interval                definition
# 0  Premise licences in force - On trade     Ayrshire & Arran  S08000015  Health board  2017  2017/18 financial year      751.0    24.98                      23.22                      26.83  rate / 10,000 population
# 1  Premise licences in force - On trade              Borders  S08000016  Health board  2017  2017/18 financial year      352.0    37.63                      33.80                      41.77  rate / 10,000 population
# 2  Premise licences in force - On trade  Dumfries & Galloway  S08000017  Health board  2017  2017/18 financial year      468.0    38.14                      34.76                      41.75  rate / 10,000 population
# 3  Premise licences in force - On trade                 Fife  S08000029  Health board  2017  2017/18 financial year      693.0    23.15                      21.46                      24.94  rate / 10,000 population
# 4  Premise licences in force - On trade         Forth Valley  S08000019  Health board  2017  2017/18 financial year      585.0    23.78                      21.89                      25.79  rate / 10,000 population

# %%
df_HB.shape
# Out:
# (988, 11)

# %%
import time
grouped_by_indicator_area_type = df_HB.groupby(['area_name','year'])
name_list = []
values_list = []
i=0
scores_per_area =[]
dict_list =[]
for pair, pair_df in grouped_by_indicator_area_type:
    #pair[0] indicator name
    #pair[2] year
   
    #print(pair_df)
    #print(pair_df.shape
    start_time = time.time()
    comparators = [find_comparator(x,y) for x,y in zip(pair_df['indicator'], pair_df['year'])]
    area_diff = find_differnce_all(comparators,pair_df['lower_confidence_interval'], pair_df['upper_confidence_interval'], pair_df['measure'])
    diff_ = create_dictionary(area_diff,pair_df['indicator'],pair[0],pair[1],pair_df['area_type'],has_intervals(pair_df['lower_confidence_interval']))
    scores_per_area.append(area_score)
    dict_list.extend(diff_)
elapsed_time = time.time() - start_time
#print(please)
#print(scores_per_area)
print(elapsed_time)
# Out:
# 0.11709046363830566

# %%
# Out:
# 988

# %%
per_area_diff = pd.DataFrame(dict_list)

# %%
per_area_diff.head()
# Out:
#         area          area_type  difference  has_intervals                                  indicator  year
# 0  Abbeyhill  Intermediate zone         7.1           True  Babies exclusively breastfed at 6-8 weeks  2003
# 1  Abbeyhill  Intermediate zone        11.5           True                       Healthy birth weight  2003
# 2  Abbeyhill  Intermediate zone         6.7           True                           Premature births  2003
# 3  Abbeyhill  Intermediate zone        19.7           True  Exposure to secondhand smoke at 6-8 weeks  2003
# 4  Abbeyhill  Intermediate zone        11.9           True  Babies exclusively breastfed at 6-8 weeks  2004

# %% [markdown]
# # Lets try to run this approach to the whole Dataset

# %% [markdown]
# ## Load the Dataset

# %%
#Indicators, load whatever data you want, at ScotphoProfile tool Format.
dataset_all = pd.read_csv("scotpho_data_extract.csv")

#Scotland values, Load the coresponding Scotland Values, it doesnt need to be sorted
Scotland_values = pd.read_excel("Scotland_comparator.xlsx")

# %% [markdown]
# ## Functions

# %%
import math
def has_confident_intervals(value):
    return (np.logical_not(np.isnan(value)))

def has_intervals(arr):
    # if we have nan means that we dont have intervals.
    #np is nan return true where is NaN and False when we have intervals
    #so we use the logical not
    #as a result we have an array where it contains true at the index that we have intervals.
    return (np.logical_not(np.isnan(arr)))

#Search function with input indicator and year and output the comparator value (Scotland value for this Comparator)
def find_comparator(indicator, year):
    a = Scotland_values.loc[(Scotland_values['year']==year) & ( Scotland_values['indicator'] == indicator)]['measure']
    if(a.empty):
        return 0
    return a.item()

#calculate the distance between the comparator and the the intervals, for one indicator at a particular area
#if our instance doesn't contain intervals, we calculate the distance between the comparator and the measure.
def find_difference(comparator,lower, upper, measure):
    if(has_confident_intervals(lower)):
        upper_diff = abs(comparator-upper)
        lower_diff = abs(comparator-lower)
        return min(upper_diff,lower_diff)
    else:
        return abs(comparator-measure)
    

#calculates the differences for an area, for each individual indicator.
def find_differnce_all(comparator_values, lower_values, upper_values,measure):
    a = [find_difference(x,y,z,d) for x,y,z,d in zip(comparator_values,lower_values,upper_values,measure)]
    return a


#creates a dictionary for a particular indicator for a specific area.
def mini_dict(diff,indicator,area,year,area_type,has_intervals):
    return {'indicator': indicator, 'area': area, 'year': year, 'area_type': area_type, 'has_intervals': has_intervals,'difference': diff}

#create a list of dictionaries for every area.
def create_dictionary(arr, indicator_names, area, year, area_type, has_intervals):
    return [mini_dict(a,b,area,year,c, d) for a,b,c,d in zip(arr, indicator_names, area_type,has_intervals)]

# %% [markdown]
# ## Run the experiment almost 16 minutes running time

# %% [markdown]
# #### This experiment follows the same approach as the above examples. I grouped the dataset by area_name and year, then I calculated the differences and I saved them into a list of Dictionaries in order to create the Data Frame

# %%
import time
grouped_by_indicator_area_type = dataset_all.groupby(['area_name','year'])

scores_per_area =[]
dict_list =[]
start_time = time.time()
for pair, pair_df in grouped_by_indicator_area_type:
    #pair[0] indicator name
    #pair[2] year
    comparators = [find_comparator(x,y) for x,y in zip(pair_df['indicator'], pair_df['year'])]
    area_diff = find_differnce_all(comparators,pair_df['lower_confidence_interval'], pair_df['upper_confidence_interval'], pair_df['measure'])
    diff_ = create_dictionary(area_diff,pair_df['indicator'],pair[0],pair[1],pair_df['area_type'],has_intervals(pair_df['lower_confidence_interval']))
    #list.extend appends only the values of a list and not a list itself.
    dict_list.extend(diff_)

elapsed_time = time.time() - start_time
print(elapsed_time)
# Out:
# 963.2258377075195

# %% [markdown]
# ## create the dataframe

# %%
per_area_diff = pd.DataFrame(dict_list)

# %%
per_area_diff
# Out:
#              area          area_type  difference  has_intervals                                          indicator  year
# 0       Abbeyhill  Intermediate zone         7.1           True          Babies exclusively breastfed at 6-8 weeks  2003
# 1       Abbeyhill  Intermediate zone        11.5           True                               Healthy birth weight  2003
# 2       Abbeyhill  Intermediate zone         6.7           True                                   Premature births  2003
# 3       Abbeyhill  Intermediate zone        19.7           True          Exposure to secondhand smoke at 6-8 weeks  2003
# 4       Abbeyhill  Intermediate zone        11.9           True          Babies exclusively breastfed at 6-8 weeks  2004
# 5       Abbeyhill  Intermediate zone        12.6           True                               Healthy birth weight  2004
# 6       Abbeyhill  Intermediate zone         3.4           True          Immunisation uptake at 24 months - 5 in 1  2004
# 7       Abbeyhill  Intermediate zone         9.6           True             Immunisation uptake at 24 months - MMR  2004
# 8       Abbeyhill  Intermediate zone         6.2           True                                   Premature births  2004
# 9       Abbeyhill  Intermediate zone        17.3           True          Exposure to secondhand smoke at 6-8 weeks  2004
# 10      Abbeyhill  Intermediate zone         6.9           True          Babies exclusively breastfed at 6-8 weeks  2005
# 11      Abbeyhill  Intermediate zone        10.7           True                               Healthy birth weight  2005
# 12      Abbeyhill  Intermediate zone         3.1           True          Immunisation uptake at 24 months - 5 in 1  2005
# 13      Abbeyhill  Intermediate zone         8.8           True             Immunisation uptake at 24 months - MMR  2005
# 14      Abbeyhill  Intermediate zone         7.2           True                                   Premature births  2005
# 15      Abbeyhill  Intermediate zone        15.7           True          Exposure to secondhand smoke at 6-8 weeks  2005
# 16      Abbeyhill  Intermediate zone         1.3           True          Babies exclusively breastfed at 6-8 weeks  2006
# 17      Abbeyhill  Intermediate zone        12.1           True                               Healthy birth weight  2006
# 18      Abbeyhill  Intermediate zone         2.8           True          Immunisation uptake at 24 months - 5 in 1  2006
# 19      Abbeyhill  Intermediate zone         6.7           True             Immunisation uptake at 24 months - MMR  2006
# 20      Abbeyhill  Intermediate zone         6.1           True                                   Premature births  2006
# 21      Abbeyhill  Intermediate zone        11.8           True          Exposure to secondhand smoke at 6-8 weeks  2006
# 22      Abbeyhill  Intermediate zone         3.3           True          Babies exclusively breastfed at 6-8 weeks  2007
# 23      Abbeyhill  Intermediate zone         9.2           True                               Healthy birth weight  2007
# 24      Abbeyhill  Intermediate zone         1.6           True          Immunisation uptake at 24 months - 5 in 1  2007
# 25      Abbeyhill  Intermediate zone         1.8           True             Immunisation uptake at 24 months - MMR  2007
# 26      Abbeyhill  Intermediate zone         6.3           True                                   Premature births  2007
# 27      Abbeyhill  Intermediate zone        13.6           True          Exposure to secondhand smoke at 6-8 weeks  2007
# 28      Abbeyhill  Intermediate zone        10.9           True          Babies exclusively breastfed at 6-8 weeks  2008
# 29      Abbeyhill  Intermediate zone        10.6           True                               Healthy birth weight  2008
# ...           ...                ...         ...            ...                                                ...   ...
# 550588     Ythsie  Intermediate zone       368.2           True                     Alcohol-related hospital stays  2016
# 550589     Ythsie  Intermediate zone         4.5           True                   Child dental health in primary 1  2016
# 550590     Ythsie  Intermediate zone         2.4           True                   Child dental health in primary 7  2016
# 550591     Ythsie  Intermediate zone         6.0           True                  Child healthy weight in primary 1  2016
# 550592     Ythsie  Intermediate zone        25.2           True                                         Crime rate  2017
# 550593     Ythsie  Intermediate zone         0.6           True                                        Live births  2017
# 550594     Ythsie  Intermediate zone   5418774.0          False            Mid-year population estimate - all ages  2017
# 550595     Ythsie  Intermediate zone         0.7           True      Mid-year population estimate - aged 1-4 years  2017
# 550596     Ythsie  Intermediate zone         1.7           True    Mid-year population estimate - aged 16-25 years  2017
# 550597     Ythsie  Intermediate zone         0.6           True     Mid-year population estimate - aged 5-15 years  2017
# 550598     Ythsie  Intermediate zone         0.1           True   Mid-year population estimate - aged under 1 year  2017
# 550599     Ythsie  Intermediate zone         1.1           True     Mid-year population estimate - aged 0-25 years  2017
# 550600     Ythsie  Intermediate zone         1.6           True     Mid-year population estimate - aged 0-15 years  2017
# 550601     Ythsie  Intermediate zone         1.6           True      Mid-year population estimate - aged 16+ years  2017
# 550602     Ythsie  Intermediate zone         1.2           True    Mid-year population estimate - aged 16-64 years  2017
# 550603     Ythsie  Intermediate zone         0.7           True    Mid-year population estimate - aged 65-74 years  2017
# 550604     Ythsie  Intermediate zone         1.9           True      Mid-year population estimate - aged 75+ years  2017
# 550605     Ythsie  Intermediate zone         0.5           True      Mid-year population estimate - aged 85+ years  2017
# 550606     Ythsie  Intermediate zone        40.7           True  People living in 15% most 'access deprived' areas  2017
# 550607     Ythsie  Intermediate zone         8.5           True                         Population income deprived  2017
# 550608     Ythsie  Intermediate zone        27.5           True    Population within 500 metres of a derelict site  2017
# 550609     Ythsie  Intermediate zone         9.8           True                             Single adult dwellings  2017
# 550610     Ythsie  Intermediate zone         7.1           True         Working age population employment deprived  2017
# 550611     Ythsie  Intermediate zone        46.7           True  Young people living in the most access deprive...  2017
# 550612     Ythsie  Intermediate zone        21.5           True  Young people living in the most crime deprived...  2017
# 550613     Ythsie  Intermediate zone        21.3           True  Young people living in the most income deprive...  2017
# 550614     Ythsie  Intermediate zone        38.4           True                     Alcohol-related hospital stays  2017
# 550615     Ythsie  Intermediate zone        10.2           True                   Child dental health in primary 1  2017
# 550616     Ythsie  Intermediate zone         4.1           True                   Child dental health in primary 7  2017
# 550617     Ythsie  Intermediate zone         5.1           True                  Child healthy weight in primary 1  2017
#
# [550618 rows x 6 columns]

# %% [markdown]
# ## Exporting to Excel

# %%
per_area_diff.to_excel("Scoring per area with differences.xlsx")
